# %% [markdown]
# # Ciclos
#
# Los ciclos nos permiten
#
# FOR "Cada_Elemento" IN "Lista":
#
# By José de Jesús Pérez

# %% [markdown]
# **texto en negrita**["Pokémon, ewew"]
# ["Pikachu","ewew"]
# [1,2,3,4]
#
# DE pokemon DENTRO pokemons
#     variable	elementos a recorrer
# 		["p","s","c"]
# for pokemon in  pokemons:
#  # pokemon = "Pikachu"
#  print(pokemon)
# print(pokemon)
#
# Pikachu
# Squirtle
# Charmander
#
# print("Pikachu")
# print("Squirtle")
# print("Charmander")
#
# pokemon = "Charmander"
#
# print(pokemon)

# %%
# FOR

alumnos = ["juan", "rogelio", "rafael", "kelvin", "jesus", "jose"]
#           0         1           2         3         4       5
# forma de acceder a un elemento de una lista
# lista[posicion]

alumno_con_suerte = alumnos[4]

pokemons = ["Pikachu", "Squirtle", "Charmander"] 
#                   0         1           2         3 

for pokemon in pokemons:
 # 1 vez -> pokemon = "Pikachu"
 # 2 vez -> pokemon = "Squirtle"
 # 3 vez -> pokemon = "Charmander"
 print(pokemon)

print('--------------')

for posicion_pokemon in range(0,3):
 #     lista        [posicion]

  # 1 vez -> posicion_pokemon = 0
 # 2 vez -> posicion_pokemon = 1
 # 3 vez -> posicion_pokemon = 2

 print(pokemons[posicion_pokemon])

print('--------------')
# print('holi')
# print(pokemon)
print(alumno_con_suerte)

print('--------------')
for i in range(2,5):
  print(alumnos[i])
# Out:
# Pikachu
# Squirtle
# Charmander
# --------------
# Pikachu
# Squirtle
# Charmander
# --------------
# jesus
# --------------
# rafael
# kelvin
# jesus

# %%
# WHILE

# imprimir del 0 al 4

# Con for
for i in range(10, 0, -2):
  print(i)

# Con while
count = 10
while(count >= 0):
  print('-----> Numero de iteracion', count + 1)
  print(count)
  #print('antes',count)
  count = count - 2
  # print('despues',count)
# Out:
# 10
# 8
# 6
# 4
# 2
# -----> Numero de iteracion 11
# 10
# -----> Numero de iteracion 9
# 8
# -----> Numero de iteracion 7
# 6
# -----> Numero de iteracion 5
# 4
# -----> Numero de iteracion 3
# 2
# -----> Numero de iteracion 1
# 0

# %%
  1 >= 5
# Out:
# False

# %%
# Condicionales

a = 200
b = 33

# si b es mayor que a : 
if b > a:
  print("b es más grande que a")
else:
  print("b no es más grande que a")
if b == a:
  print("es exactamente igual a a") 
if b == 33:
  print("b es 33")
# Out:
# b no es más grande que a
# b es 33

# %%
name = "Pikachu"
strenght = 23
if name == "Charmander" and strenght == 23:
    print("Tu nombre es Charmander, y tienes 23 de fuerza.")
if name == "Charmander" or strenght == 23 or  strenght < 1 or strenght == 45:
    print("Tu nombre es Charmander, o tienes 23 de fuerza.")
# Out:
# Tu nombre es Charmander, o tienes 23 de fuerza.

# %%
# un mal uso de una función :c
def enviarEmailJuan():
  print('conexion con el servidor...')
  print('cuerpo del mail')
  print('destinatario:')
  print('juan')
  print('hola juan, hoy no va a haber clase')
  print('enviarlo por el servidor... pip pip')
destinatario = 'luz'
# buen uso de una funcion

alumnos = ["rogelio", "rafael", "kelvin", "jesus", "jose"]

def enviarEmail(destinatario):
  print('conexion con el servidor...')
  print('cuerpo del mail')
  print('destinatario:')
  print(destinatario)
  print('hola '+ destinatario +', hoy no va a haber clase')
  print('enviarlo por el servidor... pip pip')

for alumno in alumnos[:]:
  print(alumno)
  enviarEmail(alumno)
# Out:
# rogelio
# conexion con el servidor...
# cuerpo del mail
# destinatario:
# rogelio
# hola rogelio, hoy no va a haber clase
# enviarlo por el servidor... pip pip
# rafael
# conexion con el servidor...
# cuerpo del mail
# destinatario:
# rafael
# hola rafael, hoy no va a haber clase
# enviarlo por el servidor... pip pip
# kelvin
# conexion con el servidor...
# cuerpo del mail
# destinatario:
# kelvin
# hola kelvin, hoy no va a haber clase
# enviarlo por el servidor... pip pip
# jesus
# conexion con el servidor...
# cuerpo del mail
# destinatario:
# jesus
# hola jesus, hoy no va a haber clase
# enviarlo por el servidor... pip pip
# jose
# conexion con el servidor...
# cuerpo del mail
# destinatario:
# jose
# hola jose, hoy no va a haber clase
# enviarlo por el servidor... pip pip

# %%
# print(4 + 5)

# def sumar(numero1, numero2):

def sumar(a=0, b=0):
  """
    Función para sumar dos valores llamados "a" y "b"
    que devuelve el resultado de la operación
  """
  print('a',a)
  print('b',b)
  return a + b

m = sumar(5,5)
n = sumar(4,7)

p = sumar(m,n)
print(p)
print(sumar(b=5))


help(sumar)
# Out:
# a 5
# b 5
# a 4
# b 7
# a 10
# b 11
# 21
# a 0
# b 5
# 5
# Help on function sumar in module __main__:
#
# sumar(a=0, b=0)
#     Función para sumar dos valores llamados "a" y "b"
#     que devuelve el resultado de la operación

# %%
def calcular(operacion, valor1, valor2):
  return operacion(valor1, valor2)


print(calcular(sumar,2,3))

def resta(val1, val2):
  return val1-val2

print(calcular(resta,2,3))
# Out:
# a 2
# b 3
# 5
# -1

# %%
# ¿sumar tantos números me manden?
def sumarNNumeros(*numeros):


sumarNNumeros(1,4,5,6,6,77,8,8)
sumarNNumeros(1,8,8)

# %% [markdown]
# [8,2,3,0,7]
#
#
#
#
# - sumar todos los valores
#
# ¿lo hace python?
#
# si si, ya acabé
#
# si no
#
# - ¿qué operadores, funciones, librerias* tengo?
#
# +, -, * , /, %
#
# - saber cuantos números voy a sumar
# - si puedo sumar de dos valores
# - puedo repetir una acción
#   8,2,3,0,7
#   (((8 + 2) + 3) + 0) + 7

# %%
sum([8,2,3,0,7])
# Out:
# 20

# %%
def sumarN(*args):
  total=0
  for each in args:
    total=total+each
  return total
  
def contarArgs(*args):
  numeros=0
  for each in args:
    numeros+=1
  return numeros

suma=sumarn(1,2,3,4,5,6,7,8,9)
numContados=contarArgs(1,2,3,4,5,6,7,8,9)
print(suma,numContados)
