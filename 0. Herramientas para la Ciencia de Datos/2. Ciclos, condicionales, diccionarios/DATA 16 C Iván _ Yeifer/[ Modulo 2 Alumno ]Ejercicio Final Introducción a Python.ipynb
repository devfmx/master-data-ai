# %% [markdown]
# # Evaluación de Listas

# %%
evolucion_pikachu='Raichu
evolucion_meow='Persian'

# %%
pokemon = ['Ash', 'Pikachu','James', 'Meow']

# %% [markdown]
# # Insertar evolucion_pikachu y evolucion_meow en la lista : pokemon.

# %%
# Insertar evolucion_pikachu y evolucion_meow en la lista : pokemon.

#Resultado:
#['Ash', 'pikachu', 'Raichu', 'James', 'Meow', 'Persian']

# %% [markdown]
# # ¿Charizard está en la lista: pokemon?

# %%
pokemon.index('charizard')
#Resultado:
# ValueError: 'charizard' is not in list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-97a4325cb2b8> in <module>
# ----> 1 pokemon.index('charizard')
#       2 #Resultado:
#       3 # ValueError: 'charizard' is not in list
#
# ValueError: 'charizard' is not in list

# %% [markdown]
# # Evaluación de Diccionarios

# %%
# Vamos a vaciar la lista:pokemon, en el diccionario:dict_entrenamiento, según los datos solicitados.

# %%
dict_entrenamiento = {
				"Nombre_1":"Ash"   
                ,"Pokemon_1": "Pikachu"   
                ,"Evolucion_1": "Hello!"
    
                ,"Nombre_2":   "James"
                ,"Pokemon_2":    "5454548878"
                ,"Evolucion_2": "454545454545"
}

# %%
dict_entrenamiento
# Out:
# {'Evolucion_1': 'Hello!',
#  'Evolucion_2': '454545454545',
#  'Nombre_1': 'Ash',
#  'Nombre_2': 'James',
#  'Pokemon_1': 'Pikachu',
#  'Pokemon_2': '5454548878'}

# %%
dict_entrenamiento

# %% [markdown]
# # Listar las claves del diccionario.

# %%
#Resultado
#dict_keys(['Nombre_1', 'Pokemon_1', 'Evolucion_1', 'Nombre_2', 'Pokemon_2', 'Evolucion_2'])

# %% [markdown]
# # Listar los valores del diccionario.

# %%
#Resultado
#dict_values(['Ash', 'Pikachu', 'Raichu', 'James', 'Meow', 'Persian'])

# %% [markdown]
# # Actualizar los datos del diccionario con los siguientes datos.

# %%
dict_entrenamiento.update({'Nombre_3': 'May'})
dict_entrenamiento.update({'Pokemon_3': 'Bulbasour'})
dict_entrenamiento.update({'Evolucion_3': 'Ivysaur'})

"""
Resultado
{'Nombre_1': 'Ash',
 'Pokemon_1': 'Pikachu',
 'Evolucion_1': 'Raichu',
 'Nombre_2': 'James',
 'Pokemon_2': 'Meow',
 'Evolucion_2': 'Persian',
 'Nombre_3': 'Billie'}
 
 """

# %%
dict_entrenamiento
