# %% [markdown]
# # Listas

# %%
pokemon = ['pikachu', 'charizard', 10, 1234]

# %%
pokemon
# Out:
# ['pikachu', 'charizard', 10, 1234]

# %% [markdown]
# # Métodos

# %% [markdown]
# 1. append():
#
# Este método agrega un elemento al final de una lista

# %%
pokemon.append('bulbasaur')

# %%
pokemon
# Out:
# ['pikachu', 'charizard', 10, 1234, 'bulbasaur']

# %% [markdown]
# 1. count()
# Este método recibe un elemento como argumento, y cuenta la cantidad de veces que aparece en la lista.

# %%
pokemon.count('pikachu')
# Out:
# 1

# %% [markdown]
# 2. extend()
# Este método extiende una lista agregando un iterable al final.

# %%
pokemon.extend('pikachu')

# %%
pokemon
# Out:
# ['pikachu',
#  'charizard',
#  10,
#  1234,
#  'bulbasaur',
#  'p',
#  'i',
#  'k',
#  'a',
#  'c',
#  'h',
#  'u']

# %% [markdown]
# 3. index()
# Este método recibe un elemento como argumento, y devuelve el índice de su primera aparición en la lista.

# %%
pokemon.index('charizard')
# Out:
# 1

# %% [markdown]
# 4. insert()
# Este método inserta el elemento x en la lista, en el índice i.

# %%
pokemon.insert(2,'15')

# %%
pokemon
# Out:
# ['pikachu',
#  'charizard',
#  '15',
#  10,
#  1234,
#  'bulbasaur',
#  'p',
#  'i',
#  'k',
#  'a',
#  'c',
#  'h',
#  'u']

# %% [markdown]
# 5. pop()
# Este método devuelve el último elemento de la lista, y lo borra de la misma.

# %%
pokemon.pop()
# Out:
# 'u'

# %%
pokemon
# Out:
# ['pikachu',
#  'charizard',
#  '15',
#  10,
#  1234,
#  'bulbasaur',
#  'p',
#  'i',
#  'k',
#  'a',
#  'c',
#  'h']

# %% [markdown]
# 6. remove()
# Este método recibe como argumento un elemento, y borra su primera aparición en la lista.

# %%
pokemon.remove('p')
pokemon.remove('i')
pokemon.remove('k')
pokemon.remove('a')
pokemon.remove('c')
pokemon.remove('h')

# %%
pokemon
# Out:
# ['pikachu', 'charizard', '15', 10, 1234, 'bulbasaur']

# %%
#El método devuelve un excepción ValueError si el elemento no se encuentra en la lista.
pokemon.remove('ask')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-75804f2e7bc5> in <module>
#       1 #El método devuelve un excepción ValueError si el elemento no se encuentra en la lista.
# ----> 2 pokemon.remove('ask')
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# 7. reverse()
# Este método invierte el orden de los elementos de una lista.

# %%
pokemon.reverse()

# %%
pokemon
# Out:
# ['bulbasaur', 1234, 10, '15', 'charizard', 'pikachu']

# %% [markdown]
# 8. sort()
# Este método ordena los elementos de una lista.

# %%
pokemon_numeros=[5,4,3,2,1]
pokemon_numeros.sort()

# %%
pokemon_numeros
# Out:
# [1, 2, 3, 4, 5]
