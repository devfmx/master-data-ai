# %%
from typing import List
import numpy as np
import math

# %% [markdown]
# #Vectores

# %%
vector = List[float]

v = [1.70,  # metros,
     75,   # kilos,
     40 ]  # años

#v = [1.70, 75, 40]

w = [95,   # exam1
     80,    # exam2
     75 ]   # exam3

# %%
type(v)
# Out:
# list

# %%
type(w)
# Out:
# list

# %% [markdown]
# #Matrices

# %%
matrix = List[List[float]]

A = [[1, 2, 3],  # A tiene 2 filas y 3 columnas
     [4, 5, 6]]

B = [[1, 2],     # B tiene 3 filas y 2 columnas
     [3, 4],
     [5, 6]]

# %% [markdown]
# #Operaciones

# %%
def prod_punto(v,w):
  return sum(v_i * w_i for v_i, w_i in zip(v, w))

# %%
v
# Out:
# [1.7, 75, 40]

# %%
w
# Out:
# [95, 80, 75]

# %%
for v_i, w_i in zip(v, w):
  print(v_i, w_i)
# Out:
# 1.7 95
# 75 80
# 40 75

# %%
[v_i * w_i for v_i, w_i in zip(v, w)]
# Out:
# [161.5, 6000, 3000]

# %%
sum([v_i * w_i for v_i, w_i in zip(v, w)])
# Out:
# 9161.5

# %%
prod_punto(v,w)
# Out:
# 9161.5

# %%
distancia(v,w)
# Out:
# 95.71572493587456

# %%
A+B
# Out:
# [[1, 2, 3], [4, 5, 6], [1, 2], [3, 4], [5, 6]]

# %%
arrayA = np.array(A)
arrayB = np.array(B)

type(arrayA), type(arrayB)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
arrayA + arrayA
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
A*B  #?? se puede
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-43b786f3cb40> in <module>()
# ----> 1 A*B  #?? se puede
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
arrayA * arrayB
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-591c0d58ab19> in <module>()
# ----> 1 arrayA * arrayB
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)

# %%
arrayA * arrayB.T
# Out:
# array([[ 1,  6, 15],
#        [ 8, 20, 36]])

# %%
arrayB
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arrayB.T
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
np.transpose(arrayB)
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
np.matmul(arrayA, arrayB)
# Out:
# array([[22, 28],
#        [49, 64]])
