# %% [markdown]
# **Este cuaderno es un ejercicio de un curso de [Python](https://www.kaggle.com/learn/python
# ). Puede hacer referencia al tutorial en [este enlace](https://www.kaggle.com/colinmorris/hello-python).**
#
# ---

# %% [markdown]
# Bienvenido a su primer conjunto de problemas de codificación de Python. Si es la primera vez que usa Colab, ¡bienvenido!
#
# Los cuadernos están compuestos por bloques (llamados "celdas") de texto y código. Cada uno de estos es editable, aunque principalmente editará las celdas de código para responder algunas preguntas.
#
# Para comenzar, intente ejecutar la celda de código a continuación (presionando el botón ► o haciendo clic en la celda y presionando ctrl+enter en su teclado).

# %%
print("You've successfully run some Python code")
print("Congratulations!")
# Out:
# You've successfully run some Python code
# Congratulations!

# %% [markdown]
# Intente agregar otra línea de código en la celda de arriba y vuelva a ejecutarla.
#
# Ahora seamos un poco más sofisticados: agregue una nueva celda de código haciendo clic en una celda de código existente, presionando la tecla de escape y luego presionando la tecla `a` o `b`. La tecla `a` agregará una celda arriba de la celda actual, y `b` agregará una celda debajo.
#
# ¡Estupendo! Ahora ya sabes cómo usar Notebooks.

# %% [markdown]
# # 0.
#
# *Esta es una pregunta tonta que pretende ser una introducción al formato que usamos para los ejercicios prácticos en todos los cursos de Kaggle.*
#
# **¿Cuál es tu color favorito? **
#
# Para completar esta pregunta, cree una variable llamada `color` en la celda de abajo con un valor apropiado.

# %%
# crea una variable llamada color con un valor apropiado en la línea de abajo
# (Recuerde, las cadenas en Python deben estar entre comillas "simples" o "dobles")

# %% [markdown]
# ¿No obtuviste la respuesta correcta? ¡¿Cómo es que ni siquiera sabes cuál es tu color favorito?!
#
# Elimine el `#` en la línea de abajo para hacer que una de las líneas se ejecute.
#
# Eliminar el `#` se llama descomentar, porque cambia esa línea de un "comentario" que Python no ejecuta a código, que Python sí ejecuta.

# %%
# color = "azul"

# %% [markdown]
# Las próximas preguntas funcionan de la misma manera. Lo único que cambiará son los números de las preguntas.

# %% [markdown]
# <hr/>
#
# # 1.
#
# Complete el código a continuación. En caso de que sea útil, aquí está la tabla de operaciones aritméticas disponibles:
#
#
#
# | Operador | Nombre | Descripción |
# |--------------|----------------|----------------- ---------------------------------------|
# | ``a + b`` | Adición | Suma de ``a`` y ``b`` |
# | ``a - b`` | Resta | Diferencia de ``a`` y ``b`` |
# | ``a * b`` | Multiplicación | Producto de ``a`` y ``b`` |
# | ``a/b`` | División verdadera | Cociente de ``a`` y ``b`` |
# | ``a // b`` | División de suelo | Cociente de ``a`` y ``b``, eliminando partes fraccionarias |
# | ``a % b`` | Módulo | Resto entero después de la división de ``a`` por ``b`` |
# | ``a ** b`` | Exponenciación | ``a`` elevado a la potencia de ``b`` |
# | ``-a`` | Negación | El negativo de ``a`` |
#
# <span style="display:none"></span>

# %%
pi = 3.14159 # aproximado
diámetro = 3
radio = diámetro/2
print(radio)

area_circulo = pi * (radio**2)

print(area_circulo)
# Crear una variable llamada 'radio' igual a la mitad del diámetro

# Crea una variable llamada 'área', usando la fórmula para el área de un círculo: pi por el radio al cuadrado
# Out:
# 1.5
# 7.0685775

# %%
# Descomenta las siguientes lineas para ver resultado
# radius = diameter / 2
# area = pi * radius ** 2

# %% [markdown]
# <hr/>
#
# # 2.
#
# Agregue código a la siguiente celda para intercambiar las variables `a` y `b` (de modo que `a` se refiera al objeto al que anteriormente se refería `b` y viceversa).

# %%
########### Código de configuración: no toque esta parte #####################
# Si tiene curiosidad, estos son ejemplos de listas. Hablaremos de
# ellos en profundidad algunas lecciones a partir de ahora. Por ahora, solo sepa que son
# otro tipo más de objeto de Python, como int o float.
a = [1, 2, 3]
b = [3, 2, 1]
############################################## ###################

# Su código va aquí. Intercambiar los valores a los que se refieren a y b.
# Si te quedas atascado, siempre puedes descomentar una o ambas líneas en
# la siguiente celda para una pista o para echar un vistazo a la solución.

# Pista: Intenta usar una tercera variable


print(a)
print(b)
# Out:
# [1, 2, 3]
# [3, 2, 1]

# %%
# Solución: La solución más directa es usar una tercera variable para almacenar temporalmente uno de los valores antiguos. p.ej.:

tmp = a
a = b
b = tmp

print(a)
print(b)
# Out:
# [3, 2, 1]
# [1, 2, 3]

# %% [markdown]
# <hr/>
#
# # 3a.
#
# Agrega parentesis a la siguiente expresion para que sea igual a 1

# %%
(5 - 3) // 2
# Out:
# 1

# %%
# Pista: https://es.wikipedia.org/wiki/Orden_de_evaluaci%C3%B3n

# %% [markdown]
# # 3b.  <span title="A bit spicy" style="color: darkgreen ">🌶️</span>
#
#
#
# Agrega prentesis a la siguiente operacion para que de igual a 0

# %%
8 - 3 * 2 - (1 + 1)
# Out:
# 0

# %%
# Pista, se necestia mas de un parentesis

# %% [markdown]
# <hr/>
#
# # 4.
#
# Alice, Bob y Carol acordaron juntar sus dulces de Halloween y dividirlos en partes iguales entre ellos. Por el bien de su amistad, todos los dulces sobrantes serán aplastados. Por ejemplo, si en conjunto traen a casa 91 dulces, tomarán 30 cada uno y aplastarán 1.
#
# Escribe una expresión aritmética a continuación para calcular cuántos dulces deben aplastar para cierto numero de dulces

# %%
# Variables que representan la cantidad de dulces recolectados por alice, bob y carol
dulces_alice = 121
dulces_bob = 77
dulces_carol = 109

# ¡Tu código va aquí! Reemplace el lado derecho de esta tarea con una expresión
# involucrando alice_candies, bob_candies y carol_candies
por_aplaster = -1

# %%
# `%` es el operador Modulo https://es.wikipedia.org/wiki/Operaci%C3%B3n_m%C3%B3dulo




a = 9
b = 2

print(a % b)
# Out:
# 1

# %% [markdown]
# # Sigue adelante
#
# A continuación, **[aprenderá a escribir nuevas funciones y comprenderá las funciones que escriben otros](https://www.kaggle.com/colinmorris/functions-and-getting-help)**. Esto te hará al menos 10 veces más productivo como programador de Python.
