# %% [markdown]
# # Tutorial Introductorio de Faker
# Faker es un paquete en Python que genera datos falsos por ti. Tiene la habilidad de imprimir/obtener un montón de datos falsos, por ejemplo, puede imprimir un nombre, dirección, correo, texto, etcétera.
#
# Primero que nada, vamos a instalar desde una celda el paquete con la siguiente línea:

# %%
# !pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-9.8.0-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 35.1 MB/s
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.7/dist-packages (from Faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from Faker) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->Faker) (1.15.0)
# Installing collected packages: Faker
# Successfully installed Faker-9.8.0

# %% [markdown]
# Importamos Faker y luego creamos una instancia del paquete con la variable llamada fake

# %%
from faker import Faker

# %%
fake = Faker()

# %% [markdown]
# # Métodos básicos
# Podemos crear nombres, direcciones, nombres de colores y empleos falsos con faker.

# %%
fake.color_name()
# Out:
# 'DarkSeaGreen'

# %%
fake.name()
# Out:
# 'Rachel Rogers'

# %%
fake.address()
# Out:
# 'Unit 0999 Box 8466\nDPO AA 53469'

# %%
fake.job()
# Out:
# 'Designer, jewellery'

# %%
fake.date_of_birth(minimum_age=30)
# Out:
# datetime.date(1918, 11, 5)

# %%
fake.city()
# Out:
# 'Lucasmouth'

# %%
name = fake.name()
color = fake.color_name()
city = fake.city()
job = fake.job()

print('Her name is {}. She lives in {}. Her favorite color is {}. She works as a {}'.format(name, city,color, job))
# Out:
# Her name is Kayla Solis. She lives in Phillipside. Her favorite color is LightSalmon. She works as a Civil Service administrator

# %% [markdown]
# # Creando texto

# %%
fake.text()
# Out:
# 'Mouth kind in bill television. They tonight simply president huge. Million law alone experience include represent.'

# %% [markdown]
# ## Texto utilizando un lenguaje específico

# %%
# Japanese
fake = Faker('ja_JP')
fake.text()
# Out:
# '運障害近代化する叔父ハードウェア。犯罪者本質的な普通のサワー主人人形持つ呼ぶ。マリン目的狐。\nソーススキーム極端なフレーム学生ログダイヤモンド。\n指名軸障害中世ヒットソース。呼ぶクルー倫理虐待。\nそれ不自然な管理する埋め込む参加するバス拡張。数字管理する大統領サワー舗装コンペ供給。再現するジャーナル人形電話ホイールログ。'

# %% [markdown]
# ## Texto con algunas palabras en específico

# %%
fake = Faker()

my_information = [
'cat','swimming', '21', 'hack', 'girl', 'coffee', 'flower','pink']

fake.sentence(ext_word_list=my_information)
# Out:
# 'Hack coffee girl girl hack pink 21 pink.'

# %% [markdown]
# # Crendo un perfil rápido

# %%
fake = Faker()
fake.profile()
# Out:
# {'address': '3786 Singh Parks\nLake Theresaberg, DC 51717',
#  'birthdate': datetime.date(1983, 5, 30),
#  'blood_group': 'AB+',
#  'company': 'Taylor-Brown',
#  'current_location': (Decimal('-30.618356'), Decimal('-69.673001')),
#  'job': 'Electrical engineer',
#  'mail': 'jsmith@hotmail.com',
#  'name': 'Monique Ward',
#  'residence': '159 Clark Ports\nEast Jasonville, NH 12499',
#  'sex': 'F',
#  'ssn': '786-28-1619',
#  'username': 'tsoto',
#  'website': ['https://wilson.com/']}

# %% [markdown]
# Podemos analizar lo que Faker nos regresa en un DataFrame y remover el website:

# %%
import pandas as pd

fake = Faker(['it_IT','ja_JP', 'zh_CN', 'de_DE','en_US', 'es_MX'])

profiles = [fake.profile() for i in range(100)]

df = pd.DataFrame(profiles)
df.head()
# Out:
#                    job  ...   birthdate
# 0  Medizininformatiker  ...  2013-02-26
# 1             Polizist  ...  1979-06-26
# 2              客户经理/主管  ...  1964-07-02
# 3         Set designer  ...  1983-07-09
# 4             エステティシャン  ...  1973-03-31
#
# [5 rows x 13 columns]

# %%
df = df.drop('website', axis=1)

# %%
df.head()
# Out:
#                    job  ...   birthdate
# 0  Medizininformatiker  ...  2013-02-26
# 1             Polizist  ...  1979-06-26
# 2              客户经理/主管  ...  1964-07-02
# 3         Set designer  ...  1983-07-09
# 4             エステティシャン  ...  1973-03-31
#
# [5 rows x 12 columns]

# %%
from faker import Faker 
import json                 
import numpy as np

fake = Faker() 

def create_data(x): 
  
    # dictionary 
    friends_data ={} 
    for i in range(0, x): 
        friends_data[i]={} 
        friends_data[i]['name']= fake.name() 
        friends_data[i]['address']= fake.address() 
        friends_data[i]['city']= fake.city() 
        friends_data[i]['color']= fake.color()
        friends_data[i]['closeness (1-5)'] = np.random.randint(0,5)
    
    return friends_data

# %%
friends = create_data(10)
friends
# Out:
# {0: {'address': 'USCGC Haas\nFPO AA 55673',
#   'city': 'Nelsonfurt',
#   'closeness (1-5)': 2,
#   'color': '#7ae896',
#   'name': 'James Martinez'},
#  1: {'address': '873 Valenzuela Islands\nSouth Alfred, LA 62369',
#   'city': 'Kellyfort',
#   'closeness (1-5)': 0,
#   'color': '#77ea79',
#   'name': 'Marcus Phillips'},
#  2: {'address': '25060 Joseph River\nSarahstad, CT 66952',
#   'city': 'Sloanton',
#   'closeness (1-5)': 2,
#   'color': '#ffab51',
#   'name': 'Joseph Strong'},
#  3: {'address': '369 Camacho Village\nPort Mark, FL 16602',
#   'city': 'South Kathryn',
#   'closeness (1-5)': 3,
#   'color': '#a9e3f9',
#   'name': 'Crystal Bradley'},
#  4: {'address': 'USNS Velez\nFPO AE 16584',
#   'city': 'Millertown',
#   'closeness (1-5)': 3,
#   'color': '#00967a',
#   'name': 'Alicia Alvarez'},
#  5: {'address': '074 Garcia Lake\nSouth Ruthmouth, NY 68934',
#   'city': 'West Shannonburgh',
#   'closeness (1-5)': 2,
#   'color': '#fca1a3',
#   'name': 'Michelle Jones'},
#  6: {'address': '246 Wilson Island\nHinesmouth, OH 25821',
#   'city': 'Sanchezport',
#   'closeness (1-5)': 4,
#   'color': '#61e897',
#   'name': 'Mrs. Olivia Wilson'},
#  7: {'address': '13316 Kristy Bypass\nRogershaven, CT 07691',
#   'city': 'Nashfurt',
#   'closeness (1-5)': 1,
#   'color': '#b2ffee',
#   'name': 'Peter Riley'},
#  8: {'address': '034 Michael Alley Apt. 564\nWest Karen, TX 80855',
#   'city': 'Port Laura',
#   'closeness (1-5)': 2,
#   'color': '#57d16e',
#   'name': 'Maria Hammond'},
#  9: {'address': '24182 Wilson Vista\nRobertsonshire, HI 78663',
#   'city': 'Wallaceport',
#   'closeness (1-5)': 0,
#   'color': '#74ede1',
#   'name': 'Carolyn Henderson'}}

# %%
df2 = pd.DataFrame.from_dict(friends)

# %%
df2.T.head()
# Out:
#               name  ... closeness (1-5)
# 0   James Martinez  ...               2
# 1  Marcus Phillips  ...               0
# 2    Joseph Strong  ...               2
# 3  Crystal Bradley  ...               3
# 4   Alicia Alvarez  ...               3
#
# [5 rows x 5 columns]

# %% [markdown]
# # Python Datatypes Tipos de datos en Python

# %%
fake.pybool()
# Out:
# True

# %% [markdown]
# # Creando una lista de 5 elementos con diferentes tipos de datos

# %%
fake.pylist(nb_elements=5, variable_nb_elements=True)
# Out:
# [datetime.datetime(1995, 10, 15, 4, 37, 48),
#  datetime.datetime(1992, 9, 26, 15, 34, 44),
#  'https://baker-anderson.net/wp-content/category/author.html',
#  'tatemegan@example.net']

# %% [markdown]
# # O un decimal con 5 dígitos a la izquierda y 6 a la derecha.

# %%
fake.pydecimal(left_digits=5, right_digits=6, positive=False, min_value=None, max_value=None)
# Out:
# Decimal('45318.577888')
