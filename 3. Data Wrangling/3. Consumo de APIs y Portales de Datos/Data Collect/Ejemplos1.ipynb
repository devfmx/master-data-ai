# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&key=AIzaSyCU1hggxan-Kgvy1IwxHW5JJqeyUig0uxM"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "candidates" : [
#       {
#          "formatted_address" : "140 George St, The Rocks NSW 2000澳洲",
#          "geometry" : {
#             "location" : {
#                "lat" : -33.8599358,
#                "lng" : 151.2090295
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -33.85824377010728,
#                   "lng" : 151.2104386798927
#                },
#                "southwest" : {
#                   "lat" : -33.86094342989272,
#                   "lng" : 151.2077390201073
#                }
#             }
#          },
#          "name" : "澳洲當代藝術博物館",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "rating" : 4.4
#       }
#    ],
#    "status" : "OK"
# }

# %%
print(response.status_code)
# Out:
# 200
