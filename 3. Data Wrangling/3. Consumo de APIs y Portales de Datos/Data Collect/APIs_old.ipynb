# %% [markdown]
# # Obtener Datos a través de APIs
#
# ![api](https://www.meme-arsenal.com/memes/6200d14d795eab11d26a3afabed68439.jpg)
#
# ## Que quedamos que eran...?
#
# Application Programming Interface
#
# Una serie de Reglas y maneras de comunicarnos con Aplicaciones o Sistemas  de Sw para Obtener información o construir Sw
#
#
# ## Aguantame tantito, antes tenemos que ver que sonn los json
#
#
# ### Son el estandar de como transferir los datos a través de las APIs
#
# ![json](https://i.pinimg.com/736x/7c/2a/8d/7c2a8d5b749ca8a9f313ca0e15c844a4.jpg)

# %%
import json
import pandas as pd

# %%
# Hacemos una petición para obtener el archivo JSON
# !wget https://raw.githubusercontent.com/devfmx/master-data-ai/main/Kata%20Data%20Wrangling/APIsCollect/data-text.json

# %%
# Leemos nuestro archivo JSON
json_data = open('data-text.json').read()

# %%
json_data
# Out:
# '[\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":1990,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Both sexes",\n    "Display Value":77,\n    "Numeric":77.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Both sexes",\n    "Display Value":80,\n    "Numeric":80.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Female",\n    "Display Value":28,\n    "Numeric":28.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Both sexes",\n    "Display Value":23,\n    "Numeric":23.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Eastern Mediterranean",\n    "World Bank income group":"High-income",\n    "Country":"United Arab Emirates",\n    "Sex":"Female",\n    "Display Value":78,\n    "Numeric":78.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Americas",\n    "World Bank income group":"High-income",\n    "Country":"Antigua and Barbuda",\n    "Sex":"Male",\n    "Display Value":72,\n    "Numeric":72.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":1990,\n    "WHO region":"Americas",\n    "World Bank income group":"High-income",\n    "Country":"Antigua and Barbuda",\n    "Sex":"Male",\n    "Display Value":17,\n    "Numeric":17.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Americas",\n    "World Bank income group":"High-income",\n    "Country":"Antigua and Barbuda",\n    "Sex":"Both sexes",\n    "Display Value":22,\n    "Numeric":22.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Western Pacific",\n    "World Bank income group":"High-income",\n    "Country":"Australia",\n    "Sex":"Male",\n    "Display Value":81,\n    "Numeric":81.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Western Pacific",\n    "World Bank income group":"High-income",\n    "Country":"Australia",\n    "Sex":"Both sexes",\n    "Display Value":80,\n    "Numeric":80.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Western Pacific",\n    "World Bank income group":"High-income",\n    "Country":"Australia",\n    "Sex":"Both sexes",\n    "Display Value":83,\n    "Numeric":83.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Europe",\n    "World Ban ...

# %% [markdown]
# ![json](https://pbs.twimg.com/media/ERqHayrXsAAhs9y.jpg)

# %%
data = json.loads(json_data)
data
# Out:
# [{'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 28,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 28.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'United Arab Emirates',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Antigua and Barbuda',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Antigua and Barbuda',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Antigua and Barbuda',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Australia',
#   'Display Value': 81,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 81.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Australia',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Australia',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Austria',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Austria',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Belgium',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Bahrain',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Bahrain',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bahrain',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bahamas',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Bahamas',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Barbados',
#   'Display Value': 71,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 71.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Barbados',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Barbados',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Brunei Darussalam',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Brunei Darussalam',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Brunei Darussalam',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Canada',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Canada',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Canada',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Switzerland',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Switzerland',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Switzerland',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cook Islands',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Cook Islands',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Cook Islands',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 26,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 26.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Czech Republic',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Czech Republic',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Germany',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Germany',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Germany',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Spain',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Spain',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Spain',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 81,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 81.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Finland',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Finland',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'France',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'France',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Display Value': 81,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 81.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Equatorial Guinea',
#   'Display Value': 52,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 52.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Equatorial Guinea',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Equatorial Guinea',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Greece',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Greece',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Croatia',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Croatia',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Croatia',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 68,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 68.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ireland',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ireland',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ireland',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Iceland',
#   'Display Value': 84,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 84.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Iceland',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Israel',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Israel',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Israel',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Japan',
#   'Display Value': 29,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 29.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Japan',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Japan',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Republic of Korea',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Republic of Korea',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Republic of Korea',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Kuwait',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Kuwait',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Kuwait',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Monaco',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Monaco',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Norway',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Norway',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 27,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 27.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'New Zealand',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'New Zealand',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 70,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 70.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Portugal',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Portugal',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Saudi Arabia',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 85,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 85.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 66,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 66.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 70,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 70.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Sweden',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 67,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 67.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 71,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 71.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 55,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 55.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 51,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 51.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 51,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 51.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 53,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 53.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Burkina Faso',
#   'Display Value': 48,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 48.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
# ...
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Sweden',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Sweden',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 68,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 68.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United States of America',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'United States of America',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United States of America',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 49,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 49.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 58,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 58.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 56,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 56.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 60,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 60.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Burkina Faso',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Burkina Faso',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 59,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 59.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Central African Republic',
#   'Display Value': 51,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 51.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Central African Republic',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Democratic Republic of the Congo',
#   'Display Value': 53,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 53.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Democratic Republic of the Congo',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Democratic Republic of the Congo',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Comoros',
#   'Display Value': 56,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 56.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Comoros',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Comoros',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Eritrea',
#   'Display Value': 39,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 39.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Eritrea',
#   'Display Value': 50,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 50.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Eritrea',
#   'Display Value': 13,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 13.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 50,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 50.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Ghana',
#   'Display Value': 55,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 55.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ghana',
#   'Display Value': 57,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 57.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ghana',
#   'Display Value': 62,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 62.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  ...]

# %%
midf=pd.DataFrame(data)
midf
# Out:
#                                             Indicator  ... Comments
# 0                    Life expectancy at birth (years)  ...
# 1                    Life expectancy at birth (years)  ...
# 2                   Life expectancy at age 60 (years)  ...
# 3                   Life expectancy at age 60 (years)  ...
# 4                    Life expectancy at birth (years)  ...
# ...                                               ...  ...      ...
# 4651  Healthy life expectancy (HALE) at birth (years)  ...
# 4652  Healthy life expectancy (HALE) at birth (years)  ...
# 4653  Healthy life expectancy (HALE) at birth (years)  ...
# 4654  Healthy life expectancy (HALE) at birth (years)  ...
# 4655  Healthy life expectancy (HALE) at birth (years)  ...
#
# [4656 rows x 12 columns]

# %%
# !pip install requests
import requests

# %% [markdown]
# ### Ejercicio de Sw 👇🏼

# %% [markdown]
# ### Más APIs
#
#
# ![more_apis](https://miro.medium.com/max/860/1*bopgnrkjyiu6usW4xecmqw.jpeg)
#
#
# ## API de CoinGecko Para ver status de Cryptos

# %%
coing_url = 'https://api.coingecko.com/api/v3/coins/'

#coins = requests.get(coing_url, params=params)
coins = requests.get(coing_url)
coins
# Out:
# <Response [200]>

# %%
pd.json_normalize(coins.json()).head()
# Out:
#             id symbol  ... market_data.roi.currency market_data.roi.percentage
# 0      bitcoin    btc  ...                      NaN                        NaN
# 1     ethereum    eth  ...                      btc                11258.39448
# 2  binancecoin    bnb  ...                      NaN                        NaN
# 3       tether   usdt  ...                      NaN                        NaN
# 4       solana    sol  ...                      NaN                        NaN
#
# [5 rows x 1022 columns]

# %% [markdown]
# ## Query Parameters! 🙊

# %%
# Estación Espacial Internacional

parameters = {
    "lat": 40.71,
    "lon": -74,
    "n": 9
}
response = requests.get("http://api.open-notify.org/iss-pass.json", params = parameters)
pd.json_normalize(response.json()['response'])
# Out:
#    duration    risetime
# 0       607  1638910198
# 1       657  1638916004
# 2       515  1638921854
# 3       249  1638970626
# 4       635  1638976190
# 5       638  1638981998
# 6       570  1638987888
# 7       589  1638993751
# 8       654  1638999561

# %% [markdown]
# # API de YELP para buscar Info de negocios

# %%
yelp_api_url = "https://api.yelp.com/v3/businesses/search"
params = {
    "term": "bookstore",
    "location": "San Francisco"
}

token_yelp = '0bqgbFCfWbtGN0Vq21O5XqkBOd0ipbNA7-jLUqex43fxx7KwPjTK_ZzV0xavWrYUAeLV0kfwR210cp7C_ULIK8MXOheH5sr99KYO3CVZ5ugABqrJS42hbzDxp7yvYXYx'

headers = {"Authorization": "Bearer {}".format(token_yelp)}

response = requests.get(yelp_api_url, 
                        headers=headers, 
                        params=params)

response
# Out:
# <Response [200]>

# %% [markdown]
# ## Ejemplo Explorar ThinkSpeak

# %%
api_key_yelp = '3FDPQJAUC5YDPKTV'
yelp_api_url = f"https://api.thingspeak.com/channels/1297504/fields/1.json?api_key={api_key_yelp}&results=100"

response = requests.get(yelp_api_url, 
                        api_key_yelp)

response
# Out:
# <Response [200]>

# %%
data = response.json()
data['channel']
# Out:
# {'created_at': '2021-02-04T01:35:13Z',
#  'description': 'Mediciones del agua para jitomate. 20200206 16:46',
#  'field1': 'Temperatura Inv',
#  'field2': 'Humedad Inv',
#  'field3': 'Luminosidad Inv',
#  'field4': 'EC mS',
#  'field5': 'PPM',
#  'field6': 'PH',
#  'field7': 'Temperatura Agua',
#  'field8': 'Voltaje Promedio 160',
#  'id': 1297504,
#  'last_entry_id': 1619,
#  'latitude': '0.0',
#  'longitude': '0.0',
#  'name': 'MEGA_ESP_Integrado',
#  'updated_at': '2021-05-13T00:26:43Z'}

# %% [markdown]
# ## Buscamos otro negocio en otro Lugar

# %%
YELP_API_KEY = api_key_yelp
# %store YELP_API_KEY
# Out:
# Stored 'YELP_API_KEY' (str)

# %%
params = {
    "term": "pizza",
    "location": "Mexico City"
}
yelp_api_url = "https://api.yelp.com/v3/businesses/search"
api_key_yelp
# Out:
# '3FDPQJAUC5YDPKTV'

# %%
#print(YELP_API_KEY)
headers = {"Authorization": "Bearer {}".format(token_yelp)}
response = requests.get(yelp_api_url, 
                        headers=headers, 
                        params=params)

response
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# {'businesses': [{'id': 'QbFXw_PMFP5KUhDreMuYZQ', 'alias': 'nosferatu-ciudad-de-méxico', 'name': 'Nosferatu', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/G04aZzxLSvx4TUJKBeNQ1w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/nosferatu-ciudad-de-m%C3%A9xico?adjust_creative=SqJ1gUR9oi-zVinICmsgLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SqJ1gUR9oi-zVinICmsgLw', 'review_count': 40, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 5.0, 'coordinates': {'latitude': 19.4137789112301, 'longitude': -99.173057}, 'transactions': [], 'price': '$$', 'location': {'address1': 'Calle Juan Escutia 24', 'address2': 'Col. Condesa', 'address3': '', 'city': 'Ciudad de México', 'zip_code': '06140', 'country': 'MX', 'state': 'DIF', 'display_address': ['Calle Juan Escutia 24', 'Col. Condesa', '06140 Ciudad de México, CDMX', 'Mexico']}, 'phone': '+525552117092', 'display_phone': '+52 55 5211 7092', 'distance': 6778.221533929312}, {'id': 'jG902DFJVxVvUyrhIi8kfA', 'alias': 'ginos-east-of-chicago-méxico', 'name': "Gino's East Of Chicago", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lPIS5_4APNUY0R0-oJ4_8A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/ginos-east-of-chicago-m%C3%A9xico?adjust_creative=SqJ1gUR9oi-zVinICmsgLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SqJ1gUR9oi-zVinICmsgLw', 'review_count': 2, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.5, 'coordinates': {'latitude': 19.4436268151846, 'longitude': -99.1809156511237}, 'transactions': [], 'location': {'address1': 'Lago Silverio 59', 'address2': 'Col. Anáhuac Mariano Escobedo', 'address3': '', 'city': 'México, D.F.', 'zip_code': '11320', 'country': 'MX', 'state': 'DIF', 'display_address': ['Lago Silverio 59', 'Col. Anáhuac Mariano Escobedo', '11320 México, D.F.', 'Mexico']}, 'phone': '+525552603282', 'display_phone': '+52 55 5260 3282', 'distance': 8917.707907936867}, {'id': 'fu-lEkdZy5GkEK6IcPxovg', 'alias': 'pizza-del-perro-negro-méxico-2', 'name': 'Pizza del Perro Negro', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-PbxBPBObGVZiP1AEZ36wQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pizza-del-perro-negro-m%C3%A9xico-2?adjust_creative=SqJ1gUR9oi-zVinICmsgLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SqJ1gUR9oi-zVinICmsgLw', 'review_count': 80, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 3.5, 'coordinates': {'latitude': 19.416521, 'longitude': -99.169656}, 'transactions': [], 'price': '$$', 'location': {'address1': 'Parque España 3', 'address2': 'Col. Roma', 'address3': '', 'city': 'México, D.F.', 'zip_code': '06700', 'country': 'MX', 'state': 'DIF', 'display_address': ['Parque España 3', 'Col. Roma', '06700 México, D.F.', 'Mexico']}, 'phone': '+525255339240', 'display_phone': '+52 5255339240', 'distance': 6518.7154864942695}, {'id': 'auSSBjzoJqT5f4mIMvkoNw', 'alias': 'rocco-y-simona-ciudad-de-méxico', 'name': 'Rocco & Simona', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/df4az0uIoXLk0g-G-wL8_A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rocco-y-simona-ciudad-de-m%C3%A9xico?adjust_creative=SqJ1gUR9oi-zVinICmsgLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SqJ1gUR9oi-zVinICmsgLw', 'review_count': 18, 'categories': [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.5, 'coordinates': {'latitude': 19.430442, 'longitude': -99.197328}, 'transactions': [], 'price': '$$', 'location': {'address1': 'Virgilio 8', 'address2': '', 'address3': None, 'city': 'Ciudad de México', 'zip_code': '11550', 'country': 'MX', 'state': 'DIF', 'display_address': ['Virgilio 8', '11550 Ciudad de México, CDMX', 'Mexico']}, 'phone': '+525552814716', 'display_phone': '+52 55 5281 4716', 'distance': 9771.08000580244}, {'id': 'xq5G5yIx1pwHHCR46IPPVQ', 'alias': 'dannys-pizzas-méxico', 'name': "Danny's Pizzas", 'image_url': 'htt ...

# %% [markdown]
# ## Buscando por LatLng

# %%
params = {
    "term": "pizza",
    "latitude": "19.410997",
    "longitude": "-99.1439637",
    "radius": 1500
}
yelp_api_url = "https://api.yelp.com/v3/businesses/search"
headers = {"Authorization": "Bearer {}".format(token_yelp)}
response = requests.get(yelp_api_url, 
                        headers=headers, 
                        params=params).json()

response

# %%
pd.DataFrame(response['businesses'])
# Out:
#                         id  ...     distance
# 0   hCyj6uj2fruhGxi_gsN2lQ  ...  1646.479247
# 1   4tM2GlM8gBJ8YDV7f19k6w  ...  1672.637742
# 2   NizGnZtcrl_ZwtfJaRzr-w  ...  1668.903864
# 3   KZuhFaDhcRqyLWCdz9fOWA  ...  1191.502475
# 4   yvnXVj5Xkb_0OIAgtzRVrA  ...  1188.095735
# 5   9G5RsvVl8gKOXEZnOWWb8A  ...   867.461977
# 6   3GbadRCcAohD1c1hwEzR5g  ...  1133.282471
# 7   j6rbCvCNrOYIkTOO4SbV6w  ...  1703.327587
# 8   A62yJcDQ6R-F85E7ipwHyA  ...  1670.671757
# 9   92N9v7gLtRzQSKo5PxerfQ  ...  1584.508418
# 10  gXyLONv07rQoN69VdKXVww  ...  1429.022965
# 11  eGnTz8aDwhvHiZM_YxtCjQ  ...  1751.088546
# 12  2JYqinEol1RTbtesuJyt_g  ...  1641.518199
# 13  xCDwgza8Z7amB387PXC8fw  ...  1433.832905
# 14  c7i00AlC6f8Hpm9fB6KUpw  ...  1155.397393
# 15  8-W7WcvruqM0F5ooC_-RCQ  ...  1591.897120
# 16  CygD3ii4tKcE4Xak3c3flQ  ...  1516.886097
# 17  gw8wu6Mu06YiJjyWk_FROw  ...  1818.178526
# 18  XRKLyF9FgM4dutWnjM1oqg  ...  1473.741492
# 19  G91i4T7FhB74UluWs3nayA  ...  1242.802777
#
# [20 rows x 16 columns]

# %% [markdown]
# ### Datos anidados dentro de las columnas

# %%
# bookstore[["categories", "coordinates", "location"]]

# %%
bookstore_norm = pd.json_normalize(data["businesses"],
                       sep="_")

# %%
bookstore_norm

# %%
bookstore_ultra_norm =  pd.json_normalize(data["businesses"],
                            sep="_",
                    		record_path="categories")


print(bookstore_ultra_norm.head())

# %%
# Load other business attributes and set meta prefix
flat_cafes = pd.json_normalize(data["businesses"],
                            sep="_",
                    		record_path="categories",
                    		meta=["name", 
                                  "alias",  
                                  "rating",
                                  "phone",
                                  "display_phone",
                                  "distance",
                          		  ["coordinates", "latitude"], 
                          		  ["coordinates", "longitude"]],
                    		meta_prefix="biz_")

print(flat_cafes.head())

# %% [markdown]
# # Importar Tweets! 🤯

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import collections

import tweepy as tw
import nltk
from nltk.corpus import stopwords
import re

# %%
# Si quieres obtener tus propios accesos, puedes hacerlo aquí: https://developer.twitter.com/

ACCESS_TOKEN = '168255741-3Djz0KcUiv61bazL1oWukLlWfoZLxi8MvBgGz2iC'
# %store ACCESS_TOKEN
ACCESS_TOKEN_SECRET = 'xLGldW9k8i8iJpjSKqIpp4wNpqFDeGLGnOEPDnwGjtIAo'
# %store ACCESS_TOKEN_SECRET

API_KEY = 'SGFZTl0JXlTcHZBSMQvCuk3ud'
# %store API_KEY
API_SECRET = 'IlRjxECBiahfXHMqF8hIl3dQpZC0gfGz7qobWyUi8QuustDrr2'
# %store API_SECRET

# %%
# Pass OAuth details to tweepy's OAuth handler

# %store -r ACCESS_TOKEN
# %store -r ACCESS_TOKEN_SECRET
# %store -r API_KEY
# %store -r API_SECRET

# %%
auth = tw.OAuthHandler(API_KEY, API_SECRET)

# %%
auth

# %%
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tw.API(auth)

# %%
public_tweets = api.home_timeline()
holi = []
for tweet in public_tweets:
    print(tweet._json)
    holi.append(tweet._json)
holi
pd.DataFrame(holi)

# %%
me_tweets = api.user_timeline(screen_name="@HectorCastelan", count=5)
holi = []
for tweet in me_tweets:
    print(tweet._json)
    holi.append(tweet._json)
holi
pd.DataFrame(holi)

# %%
me_tweets =  api.get_user(screen_name="@devf", count=5)
print(me_tweets._json)
# Out:
# {'id': 34894993, 'id_str': '34894993', 'name': 'Devin Flesch', 'screen_name': 'devf', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Fri Apr 24 10:32:53 +0000 2009', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'status': {'created_at': 'Fri Apr 24 10:36:50 +0000 2009', 'id': 1602632899, 'id_str': '1602632899', 'text': 'Is wondering how this works...', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}

# %%
#Contruir solo con algunas columnas (.keys())

public_tweets = api.home_timeline(count=5)
holi = []
for tweet in public_tweets:
    print(tweet._json)
    holi.append(tweet._json)
pd.DataFrame(holi, columns=['text', 'lang'])
# Out:
# {'created_at': 'Tue Dec 07 21:01:10 +0000 2021', 'id': 1468324729304104968, 'id_str': '1468324729304104968', 'text': 'Gee whiz - 𝚐𝚙𝚒𝚗𝚐 sure is a nice-looking 𝚙𝚒𝚗𝚐 alternative 📉 📈 https://t.co/JGQPrJ1B4Y https://t.co/CoQXw9GBs3', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/JGQPrJ1B4Y', 'expanded_url': 'https://github.com/orf/gping', 'display_url': 'github.com/orf/gping', 'indices': [61, 84]}], 'media': [{'id': 1468324690603253760, 'id_str': '1468324690603253760', 'indices': [85, 108], 'media_url': 'http://pbs.twimg.com/media/FGCJjrLXEAMTThG.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FGCJjrLXEAMTThG.jpg', 'url': 'https://t.co/CoQXw9GBs3', 'display_url': 'pic.twitter.com/CoQXw9GBs3', 'expanded_url': 'https://twitter.com/github/status/1468324729304104968/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1468324690603253760, 'id_str': '1468324690603253760', 'indices': [85, 108], 'media_url': 'http://pbs.twimg.com/media/FGCJjrLXEAMTThG.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FGCJjrLXEAMTThG.jpg', 'url': 'https://t.co/CoQXw9GBs3', 'display_url': 'pic.twitter.com/CoQXw9GBs3', 'expanded_url': 'https://twitter.com/github/status/1468324729304104968/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}, 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 34133, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/1468324690603253760/pl/mRFMbKiKsj48m7b9.m3u8?tag=14&container=fmp4'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1468324690603253760/vid/1280x720/ni34UyJS6bVe7cNm.mp4?tag=14'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1468324690603253760/vid/640x360/BjjClRuVfyv9WyLM.mp4?tag=14'}, {'bitrate': 288000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1468324690603253760/vid/480x270/8XBSLOY6xe351O31.mp4?tag=14'}]}, 'additional_media_info': {'title': 'gping - ping, but with a graph', 'monetizable': False}}]}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 13334762, 'id_str': '13334762', 'name': 'GitHub', 'screen_name': 'github', 'location': 'San Francisco, CA', 'description': 'How people build software. \n\nNeed help? Send us a message at https://t.co/YU5nzbpDIg for support.', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/YU5nzbpDIg', 'expanded_url': 'http://git.io/c', 'display_url': 'git.io/c', 'indices': [61, 84]}]}}, 'protected': False, 'followers_count': 2182288, 'friends_count': 326, 'listed_count': 16811, 'created_at': 'Mon Feb 11 04:41:50 +0000 2008', 'favourites_count': 5270, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 6665, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'EEEEEE', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1414990564408262661/r6YemvF9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1414990564408262661/r6YemvF9_normal. ...
# {'created_at': 'Tue Dec 07 21:01:02 +0000 2021', 'id': 1468324697926516736, 'id_str': '1468324697926516736', 'text': 'Sony Pictures producer Amy Pascal confirmed in an interview that “We are in the planning stages right now [for Veno… https://t.co/WitLseBcjo', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/WitLseBcjo', 'expanded_url': 'https://twitter.com/i/web/status/1468324697926516736', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18927441, 'id_str': '18927441', 'name': 'IGN', 'screen_name': 'IGN', 'location': '', 'description': "We're all about video games, movies, TV, and comics! Play IGN 25: The Game now! https://t.co/wP9i2hy2Vv", 'url': 'https://t.co/pmQRSNI5pm', 'entities': {'url': {'urls': [{'url': 'https://t.co/pmQRSNI5pm', 'expanded_url': 'https://www.ign.com/', 'display_url': 'ign.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/wP9i2hy2Vv', 'expanded_url': 'http://ign.com/ign25thegame', 'display_url': 'ign.com/ign25thegame', 'indices': [80, 103]}]}}, 'protected': False, 'followers_count': 8456060, 'friends_count': 1366, 'listed_count': 24882, 'created_at': 'Tue Jan 13 03:56:38 +0000 2009', 'favourites_count': 16218, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 157463, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1467946804855644161/uxoh80SK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1467946804855644161/uxoh80SK_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18927441/1638820768', 'profile_link_color': 'D3222A', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3, 'favorite_count': 7, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}
# {'created_at': 'Tue Dec 07 21:00:55 +0000 2021', 'id': 1468324666695913472, 'id_str': '1468324666695913472', 'text': 'Este año las autoridades del encuentro sumaron esfuerzos para el regreso a lo presencial con una serie de actividad… https://t.co/qC436kGXVs', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/qC436kGXVs', 'expanded_url': 'https://twitter.com/i/web/status/1468324666695913472', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 41156599, 'id_str': '41156599', 'name': 'Proceso', 'screen_name': 'proceso', 'location': 'México', 'description': 'Información y análisis https://t.co/M08hBOeUOf', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/M08hBOeUOf', 'expanded_url': 'http://proceso.com.mx', 'display_url': 'proceso.com.mx', 'indices': [23, 46]}]}}, 'protected': False, 'followers_count': 5024757, 'friends_count': 1709, 'listed_count': 14241, 'created_at': 'Tue May 19 17:00:37 +0000 2009', 'favourites_count': 1941, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 207531, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'EBEBEB', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/791445782024949760/_Mlnv2Z-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/791445782024949760/_Mlnv2Z-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/41156599/1638816187', 'profile_link_color': '990000', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F3F3F3', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'es'}
# {'created_at': 'Tue Dec 07 21:00:39 +0000 2021', 'id': 1468324599507177475, 'id_str': '1468324599507177475', 'text': 'Científicos encuentran formas de mejorar la yuca, una "cosecha de desigualdad"\nhttps://t.co/ljnQtxqxNe https://t.co/hjn6JbdAYt', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ljnQtxqxNe', 'expanded_url': 'https://buff.ly/3muF4Qm', 'display_url': 'buff.ly/3muF4Qm', 'indices': [79, 102]}], 'media': [{'id': 1468324596722155534, 'id_str': '1468324596722155534', 'indices': [103, 126], 'media_url': 'http://pbs.twimg.com/media/FGCJcPKXwA4LwcC.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FGCJcPKXwA4LwcC.jpg', 'url': 'https://t.co/hjn6JbdAYt', 'display_url': 'pic.twitter.com/hjn6JbdAYt', 'expanded_url': 'https://twitter.com/VozCientifica/status/1468324599507177475/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 800, 'h': 480, 'resize': 'fit'}, 'large': {'w': 800, 'h': 480, 'resize': 'fit'}, 'small': {'w': 680, 'h': 408, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1468324596722155534, 'id_str': '1468324596722155534', 'indices': [103, 126], 'media_url': 'http://pbs.twimg.com/media/FGCJcPKXwA4LwcC.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FGCJcPKXwA4LwcC.jpg', 'url': 'https://t.co/hjn6JbdAYt', 'display_url': 'pic.twitter.com/hjn6JbdAYt', 'expanded_url': 'https://twitter.com/VozCientifica/status/1468324599507177475/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 800, 'h': 480, 'resize': 'fit'}, 'large': {'w': 800, 'h': 480, 'resize': 'fit'}, 'small': {'w': 680, 'h': 408, 'resize': 'fit'}}}]}, 'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3305807722, 'id_str': '3305807722', 'name': 'VOZ CIENTIFICA', 'screen_name': 'VozCientifica', 'location': 'GLOBAL', 'description': 'Recopilación de artículos de los mejores blogs de divulgación científica. Porque la ciencia necesita voces...', 'url': 'https://t.co/8hEtmNT7Ti', 'entities': {'url': {'urls': [{'url': 'https://t.co/8hEtmNT7Ti', 'expanded_url': 'https://www.instagram.com/vozcientifica/', 'display_url': 'instagram.com/vozcientifica/', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 31997, 'friends_count': 29134, 'listed_count': 396, 'created_at': 'Mon Jun 01 16:58:39 +0000 2015', 'favourites_count': 54, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 18937, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/605462331234119683/e9sag3Dd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/605462331234119683/e9sag3Dd_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3305807722/1433190710', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, ...
# {'created_at': 'Tue Dec 07 21:00:38 +0000 2021', 'id': 1468324596591984640, 'id_str': '1468324596591984640', 'text': '😣 Padecimiento 162: La ruta para reconocer al burnout como enfermedad de trabajo https://t.co/SHidJ8RUQp https://t.co/sBCBiizdVr', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/SHidJ8RUQp', 'expanded_url': 'https://bit.ly/3lIy98n', 'display_url': 'bit.ly/3lIy98n', 'indices': [81, 104]}], 'media': [{'id': 1468324592355737604, 'id_str': '1468324592355737604', 'indices': [105, 128], 'media_url': 'http://pbs.twimg.com/media/FGCJb-5VgAQLCie.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FGCJb-5VgAQLCie.jpg', 'url': 'https://t.co/sBCBiizdVr', 'display_url': 'pic.twitter.com/sBCBiizdVr', 'expanded_url': 'https://twitter.com/eleconomista/status/1468324596591984640/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 464, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 760, 'h': 519, 'resize': 'fit'}, 'medium': {'w': 760, 'h': 519, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1468324592355737604, 'id_str': '1468324592355737604', 'indices': [105, 128], 'media_url': 'http://pbs.twimg.com/media/FGCJb-5VgAQLCie.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FGCJb-5VgAQLCie.jpg', 'url': 'https://t.co/sBCBiizdVr', 'display_url': 'pic.twitter.com/sBCBiizdVr', 'expanded_url': 'https://twitter.com/eleconomista/status/1468324596591984640/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 464, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 760, 'h': 519, 'resize': 'fit'}, 'medium': {'w': 760, 'h': 519, 'resize': 'fit'}}}]}, 'source': '<a href="http://www.socialbakers.com/" rel="nofollow">Emplifi</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 14917589, 'id_str': '14917589', 'name': 'El Economista', 'screen_name': 'eleconomista', 'location': 'México, DF', 'description': 'Somos el diario económico, financiero y de negocios de México, fundado en 1988. Hablamos con los profesionales.', 'url': 'https://t.co/jF2Wln8N97', 'entities': {'url': {'urls': [{'url': 'https://t.co/jF2Wln8N97', 'expanded_url': 'http://eleconomista.com.mx', 'display_url': 'eleconomista.com.mx', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 790666, 'friends_count': 103, 'listed_count': 5007, 'created_at': 'Tue May 27 06:07:11 +0000 2008', 'favourites_count': 4418, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 514189, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C4DBE1', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1410474081741312002/NHWBB6Kr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1410474081741312002/NHWBB6Kr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14917589/1628611972', 'profile_link_color': '006595', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '66CCFF', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sens ...
#                                                 text lang
# 0  Gee whiz - 𝚐𝚙𝚒𝚗𝚐 sure is a nice-looking 𝚙𝚒𝚗𝚐 a...   en
# 1  Sony Pictures producer Amy Pascal confirmed in...   en
# 2  Este año las autoridades del encuentro sumaron...   es
# 3  Científicos encuentran formas de mejorar la yu...   es
# 4  😣 Padecimiento 162: La ruta para reconocer al ...   es

# %%
search_term = "#elon+musk -filter:retweets"

tweets = tw.Cursor(api.search,
                   q=search_term,
                   lang="en",
                   since='2019-12-01').items(500)

all_tweets = [tweet.text for tweet in tweets]

all_tweets[:5]
# Out:
# ['So, #Elon is suggesting a jugular killing for the 3Bs Bill (Build Back Better)? Biden must be furious. lool\n\n“I don… https://t.co/QNE7vVT7uC',
#  'Elon Musk: i love cats i have a cat #catecoin #CATE #CateArmy #ElonMusk #ELON #ELONGATE #Bitcoin #binance',
#  "#Elon #Musk sends dire end of the world warning: 'Civilisation is going to crumble' https://t.co/6fk9zXi0Gt https://t.co/3AXb8vT6Xg",
#  'Haha they definitely didn’t learn! @elonmusk papa musk pls destroy shorts for the rest of the decade and keep sendi… https://t.co/KJZLStBqZE',
#  "@creta1829 @cryptogems555 You do not worry about me.  To me, #elon_musk's father is a myth and a savior.  I am happ… https://t.co/4Twhvkn5ae"]

# %%
def remove_url(txt):
    """Replace URLs found in a text string with nothing 
    (i.e. it will remove the URL from the string).

    Parameters
    ----------
    txt : string
        A text string that you want to parse and remove urls.

    Returns
    -------
    The same txt string with url's removed.
    """

    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
all_tweets_no_urls = [remove_url(tweet) for tweet in all_tweets]
all_tweets_no_urls[:5]
# Out:
# ['So Elon is suggesting a jugular killing for the 3Bs Bill Build Back Better Biden must be furious loolI don',
#  'Elon Musk i love cats i have a cat catecoin CATE CateArmy ElonMusk ELON ELONGATE Bitcoin binance',
#  'Elon Musk sends dire end of the world warning Civilisation is going to crumble',
#  'Haha they definitely didnt learn elonmusk papa musk pls destroy shorts for the rest of the decade and keep sendi',
#  'creta1829 cryptogems555 You do not worry about me To me elonmusks father is a myth and a savior I am happ']

# %%
all_tweets_no_urls[0].lower().split()

# %%
words_in_tweet = [tweet.lower().split() for tweet in all_tweets_no_urls]
words_in_tweet

# %%
# List of all words across tweets
all_words_no_urls = list(itertools.chain(*words_in_tweet))
all_words_no_urls

# %%
# Create counter
counts_no_urls = collections.Counter(all_words_no_urls)

counts_no_urls.most_common(50)

# %%
clean_tweets_no_urls = pd.DataFrame(counts_no_urls.most_common(15),
                             columns=['words', 'count'])

clean_tweets_no_urls.head()

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# View a few words from the set
list(stop_words)[0:10]
# Out:
# ['because', 'all', 'will', 'over', 'weren', 'me', 'it', 'was', "aren't", 'and']

# %%
# Remove stop words from each tweet list of words
tweets_nsw = [[word for word in tweet_words if not word in stop_words]
              for tweet_words in words_in_tweet]

# %%
tweets_nsw

# %%
all_words_nsw = list(itertools.chain(*tweets_nsw))

counts_nsw = collections.Counter(all_words_nsw)

counts_nsw.most_common(15)

# %%
clean_tweets_nsw = pd.DataFrame(counts_nsw.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_nsw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in Tweets (Without Stop Words)")

plt.show()

# %% [markdown]
# ![multiple_Apis](https://www.meme-arsenal.com/memes/d8d0c1244d221317e4396cd294823f73.jpg)
#
#
# #### Github of Public APIS👇🏼
#
#
# https://github.com/public-apis/public-apis
