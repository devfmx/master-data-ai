# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open('Base_Principal').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# [['Nombre(s)', 'Apellido Paterno', 'Apellido Materno', 'Edad', 'Fecha de Nacimiento', 'Personaje Marvel Favorito', 'Peícula o Serie Favorita de Marvel', 'Usuario'], ['Aksley Shadir', 'Rios', 'Ballina', '29', '5/7/1992', 'Groot', 'Guardianes de la Galaxia Vol 1', 'soluciones.analiticas.mat@gmail.com'], ['Efrain', 'Tlapale', 'Pulido', '24', '12/12/1996', 'Spider-man', 'Spider-man 2', 'tlapalepulidoefrain@gmail.com'], ['Anahi', 'Cerecero', 'Rangel', '27', '8/3/1994', 'Dr. Strange', 'Guardianes de la Galaxia 1', 'anahi.cereceror@gmail.com'], ['Carlos Adrian', 'De Labra', 'Rivera', '25', '9/10/1996', 'Cap. America', 'Guardianes de la Galaxia', 'carderiv@gmail.com'], ['Tomas', 'Tlapale', 'Pulido', '27', '10/25/1993', 'Magneto', 'Logan', 'tlapalep@gmail.com'], ['Luis', 'Quintanilla', 'Bautista', '42', '9/30/1979', 'Spiderman', 'Señor de los anillos', 'lquintanillab@gmail.com'], ['Jorge Eliecer', 'Forero', 'Luque', '31', '6/11/1990', 'Luis', 'Winter Soldier', 'jforeroluque@gmail.com']]
#                0  ...                                    7
# 0      Nombre(s)  ...                              Usuario
# 1  Aksley Shadir  ...  soluciones.analiticas.mat@gmail.com
# 2         Efrain  ...        tlapalepulidoefrain@gmail.com
# 3          Anahi  ...            anahi.cereceror@gmail.com
# 4  Carlos Adrian  ...                   carderiv@gmail.com
# 5          Tomas  ...                   tlapalep@gmail.com
# 6           Luis  ...              lquintanillab@gmail.com
# 7  Jorge Eliecer  ...               jforeroluque@gmail.com
#
# [8 rows x 8 columns]

# %%
df = pd.DataFrame.from_records(rows)
df
# Out:
#                0  ...                                    7
# 0      Nombre(s)  ...                              Usuario
# 1  Aksley Shadir  ...  soluciones.analiticas.mat@gmail.com
# 2         Efrain  ...        tlapalepulidoefrain@gmail.com
# 3          Anahi  ...            anahi.cereceror@gmail.com
# 4  Carlos Adrian  ...                   carderiv@gmail.com
# 5          Tomas  ...                   tlapalep@gmail.com
# 6           Luis  ...              lquintanillab@gmail.com
# 7  Jorge Eliecer  ...               jforeroluque@gmail.com
#
# [8 rows x 8 columns]

# %%
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df
# Out:
# 0      Nombre(s)  ...                              Usuario
# 1  Aksley Shadir  ...  soluciones.analiticas.mat@gmail.com
# 2         Efrain  ...        tlapalepulidoefrain@gmail.com
# 3          Anahi  ...            anahi.cereceror@gmail.com
# 4  Carlos Adrian  ...                   carderiv@gmail.com
# 5          Tomas  ...                   tlapalep@gmail.com
# 6           Luis  ...              lquintanillab@gmail.com
# 7  Jorge Eliecer  ...               jforeroluque@gmail.com
#
# [7 rows x 8 columns]
