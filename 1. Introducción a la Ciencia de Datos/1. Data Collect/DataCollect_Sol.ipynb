# %% [markdown]
# # Importación de datos
#
# ![importing](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSnZjzMMGgMslxI7kRbTcWMmimnCLWqAC7sPA&usqp=CAU)

# %% [markdown]
# ## Importar archivo CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

# %%
csvfile = open('drive/MyDrive/Colab Notebooks/data/data-text.csv', 'r')

# %%
reader = csv.reader(csvfile)

# %%
for row in reader:
    print(row)

# %%
with open('drive/MyDrive/Colab Notebooks/data/data-text.csv', 'r') as file:
    print(file.read())

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd

# %%
pd.read_csv('drive/MyDrive/Colab Notebooks/data/data-text.csv')

# %% [markdown]
# ### Importar Excel
# ![image.png](attachment:50447acd-8b9a-4d79-bb7e-b9dfae1b0080.png)

# %%
excel = pd.ExcelFile('drive/MyDrive/Colab Notebooks/data/tags.xlsx')

# %%
excel.sheet_names
# Out:
# ['tags']

# %%
excel.parse('tags')
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %% [markdown]
# ## Importar archivo JSON
#
# ![json](https://i.pinimg.com/736x/7c/2a/8d/7c2a8d5b749ca8a9f313ca0e15c844a4.jpg)

# %%
import json

# %%
json_data = open('drive/MyDrive/Colab Notebooks/data/data-text.json').read()

# %%
json_data
# Out:
# '[\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":1990,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Both sexes",\n    "Display Value":77,\n    "Numeric":77.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Both sexes",\n    "Display Value":80,\n    "Numeric":80.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Female",\n    "Display Value":28,\n    "Numeric":28.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Europe",\n    "World Bank income group":"High-income",\n    "Country":"Andorra",\n    "Sex":"Both sexes",\n    "Display Value":23,\n    "Numeric":23.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Eastern Mediterranean",\n    "World Bank income group":"High-income",\n    "Country":"United Arab Emirates",\n    "Sex":"Female",\n    "Display Value":78,\n    "Numeric":78.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Americas",\n    "World Bank income group":"High-income",\n    "Country":"Antigua and Barbuda",\n    "Sex":"Male",\n    "Display Value":72,\n    "Numeric":72.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":1990,\n    "WHO region":"Americas",\n    "World Bank income group":"High-income",\n    "Country":"Antigua and Barbuda",\n    "Sex":"Male",\n    "Display Value":17,\n    "Numeric":17.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at age 60 (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Americas",\n    "World Bank income group":"High-income",\n    "Country":"Antigua and Barbuda",\n    "Sex":"Both sexes",\n    "Display Value":22,\n    "Numeric":22.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Western Pacific",\n    "World Bank income group":"High-income",\n    "Country":"Australia",\n    "Sex":"Male",\n    "Display Value":81,\n    "Numeric":81.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2000,\n    "WHO region":"Western Pacific",\n    "World Bank income group":"High-income",\n    "Country":"Australia",\n    "Sex":"Both sexes",\n    "Display Value":80,\n    "Numeric":80.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Western Pacific",\n    "World Bank income group":"High-income",\n    "Country":"Australia",\n    "Sex":"Both sexes",\n    "Display Value":83,\n    "Numeric":83.00000,\n    "Low":"",\n    "High":"",\n    "Comments":""\n  },\n  {\n    "Indicator":"Life expectancy at birth (years)",\n    "PUBLISH STATES":"Published",\n    "Year":2012,\n    "WHO region":"Europe",\n    "World Ban ...

# %% [markdown]
# ![json](https://pbs.twimg.com/media/ERqHayrXsAAhs9y.jpg)

# %%
data = json.loads(json_data)

# %%
data
# Out:
# [{'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 28,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 28.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Andorra',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'United Arab Emirates',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Antigua and Barbuda',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Antigua and Barbuda',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Antigua and Barbuda',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Australia',
#   'Display Value': 81,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 81.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Australia',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Australia',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Austria',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Austria',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Belgium',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Bahrain',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Bahrain',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bahrain',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bahamas',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Bahamas',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Barbados',
#   'Display Value': 71,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 71.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Barbados',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Barbados',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Brunei Darussalam',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Brunei Darussalam',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Brunei Darussalam',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Canada',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Canada',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Canada',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Switzerland',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Switzerland',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Switzerland',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cook Islands',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Cook Islands',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Cook Islands',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Cyprus',
#   'Display Value': 26,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 26.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Czech Republic',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Czech Republic',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Germany',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Germany',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Germany',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Denmark',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Spain',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Spain',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Spain',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 81,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 81.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Estonia',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Finland',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Finland',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'France',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'France',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Display Value': 81,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 81.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Equatorial Guinea',
#   'Display Value': 52,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 52.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Equatorial Guinea',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Equatorial Guinea',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Greece',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Greece',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Croatia',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Croatia',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Croatia',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 68,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 68.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Hungary',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ireland',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ireland',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ireland',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Iceland',
#   'Display Value': 84,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 84.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Iceland',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Israel',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Israel',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Israel',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Italy',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Japan',
#   'Display Value': 29,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 29.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Japan',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Japan',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Republic of Korea',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Republic of Korea',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Republic of Korea',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Kuwait',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Kuwait',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Kuwait',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 75,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 75.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Luxembourg',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Monaco',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Monaco',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Malta',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Norway',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Norway',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Nauru',
#   'Display Value': 27,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 27.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'New Zealand',
#   'Display Value': 79,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 79.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'New Zealand',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 70,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 70.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Oman',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Portugal',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Portugal',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Qatar',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Saudi Arabia',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 85,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 85.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 20,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 20.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 22,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 22.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 25,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 25.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 66,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 66.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 73,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 73.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 76,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 76.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 70,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 70.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 83,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 83.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 74,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 74.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 19,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 19.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Sweden',
#   'Display Value': 78,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 78.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 67,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 67.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 71,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 71.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 55,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 55.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 51,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 51.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 51,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 51.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 53,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 53.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Burkina Faso',
#   'Display Value': 48,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 48.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
# ...
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'San Marino',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovakia',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 72,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 72.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 77,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 77.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 80,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 80.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Slovenia',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Sweden',
#   'Display Value': 82,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 82.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Sweden',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 68,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 68.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Trinidad and Tobago',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United States of America',
#   'Display Value': 23,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 23.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'United States of America',
#   'Display Value': 24,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 24.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'United States of America',
#   'Display Value': 21,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 21.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 49,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 49.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 58,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 58.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Afghanistan',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Burundi',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 56,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 56.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 60,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 60.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Benin',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Burkina Faso',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Burkina Faso',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 59,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 59.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Bangladesh',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Central African Republic',
#   'Display Value': 51,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 51.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Central African Republic',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Democratic Republic of the Congo',
#   'Display Value': 53,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 53.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Democratic Republic of the Congo',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Democratic Republic of the Congo',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Comoros',
#   'Display Value': 56,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 56.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Comoros',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Comoros',
#   'Display Value': 15,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 15.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Eritrea',
#   'Display Value': 39,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 39.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Eritrea',
#   'Display Value': 50,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 50.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Eritrea',
#   'Display Value': 13,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 13.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Female',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 50,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 50.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 14,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 14.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 17,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 17.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 16,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 16.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2000},
#  {'Comments': '',
#   'Country': 'Ethiopia',
#   'Display Value': 18,
#   'High': '',
#   'Indicator': 'Life expectancy at age 60 (years)',
#   'Low': '',
#   'Numeric': 18.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  {'Comments': '',
#   'Country': 'Ghana',
#   'Display Value': 55,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 55.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Male',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ghana',
#   'Display Value': 57,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 57.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 1990},
#  {'Comments': '',
#   'Country': 'Ghana',
#   'Display Value': 62,
#   'High': '',
#   'Indicator': 'Life expectancy at birth (years)',
#   'Low': '',
#   'Numeric': 62.0,
#   'PUBLISH STATES': 'Published',
#   'Sex': 'Both sexes',
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Year': 2012},
#  ...]

# %%
pd.DataFrame(data)
# Out:
#                                             Indicator  ... Comments
# 0                    Life expectancy at birth (years)  ...
# 1                    Life expectancy at birth (years)  ...
# 2                   Life expectancy at age 60 (years)  ...
# 3                   Life expectancy at age 60 (years)  ...
# 4                    Life expectancy at birth (years)  ...
# ...                                               ...  ...      ...
# 4651  Healthy life expectancy (HALE) at birth (years)  ...
# 4652  Healthy life expectancy (HALE) at birth (years)  ...
# 4653  Healthy life expectancy (HALE) at birth (years)  ...
# 4654  Healthy life expectancy (HALE) at birth (years)  ...
# 4655  Healthy life expectancy (HALE) at birth (years)  ...
#
# [4656 rows x 12 columns]

# %% [markdown]
# # Obtener datos de una API

# %%
# !conda install requests
import requests

# %%
response = requests.get("http://api.open-notify.org/this-api-doesnt-exist")

# %%
response
# Out:
# <Response [404]>

# %%
response = requests.get("http://api.open-notify.org/astros.json")

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ![img](https://cdn.generadormemes.com/media/created/dy9twxupc4dn5pkur42gfpasnnaljd1pcdyibdv2x1qzon4ydazr1ykes8vi0ke.jpg)

# %%
data = response.json()

# %%
data
# Out:
# {'message': 'success',
#  'number': 10,
#  'people': [{'craft': 'ISS', 'name': 'Mark Vande Hei'},
#   {'craft': 'ISS', 'name': 'Pyotr Dubrov'},
#   {'craft': 'ISS', 'name': 'Anton Shkaplerov'},
#   {'craft': 'Shenzhou 13', 'name': 'Zhai Zhigang'},
#   {'craft': 'Shenzhou 13', 'name': 'Wang Yaping'},
#   {'craft': 'Shenzhou 13', 'name': 'Ye Guangfu'},
#   {'craft': 'ISS', 'name': 'Raja Chari'},
#   {'craft': 'ISS', 'name': 'Tom Marshburn'},
#   {'craft': 'ISS', 'name': 'Kayla Barron'},
#   {'craft': 'ISS', 'name': 'Matthias Maurer'}]}

# %%
pdf = pd.DataFrame(data["people"])
pdf
# Out:
#          craft              name
# 0          ISS    Mark Vande Hei
# 1          ISS      Pyotr Dubrov
# 2          ISS  Anton Shkaplerov
# 3  Shenzhou 13      Zhai Zhigang
# 4  Shenzhou 13       Wang Yaping
# 5  Shenzhou 13        Ye Guangfu
# 6          ISS        Raja Chari
# 7          ISS     Tom Marshburn
# 8          ISS      Kayla Barron
# 9          ISS   Matthias Maurer

# %%
pdf.loc[0,['craft','name']]
# Out:
# craft               ISS
# name     Mark Vande Hei
# Name: 0, dtype: object

# %%
pdf.head(1)
# Out:
#   craft            name
# 0   ISS  Mark Vande Hei

# %%
parameters = {
    "lat": 40.71,
    "lon": -74,
    "n": 9
}

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json", params = parameters)

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1646870444,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 9},
#  'response': [{'duration': 474, 'risetime': 1646877210},
#   {'duration': 654, 'risetime': 1646882890},
#   {'duration': 614, 'risetime': 1646888734},
#   {'duration': 562, 'risetime': 1646894624},
#   {'duration': 610, 'risetime': 1646900464},
#   {'duration': 653, 'risetime': 1646906267},
#   {'duration': 483, 'risetime': 1646912124},
#   {'duration': 318, 'risetime': 1646960821},
#   {'duration': 641, 'risetime': 1646966418}]}
