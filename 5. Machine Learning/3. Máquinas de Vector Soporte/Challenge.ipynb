# %% [markdown]
# # Configuración

# %%
# Python ≥3.5
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 
import sklearn
assert sklearn.__version__ >= "0.20"

import numpy as np
import os

# para que sean estables los resultados en todas las ejecuciones
np.random.seed(42)

# Para vernos pros con nuestras figuras
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# # Indicaciones
