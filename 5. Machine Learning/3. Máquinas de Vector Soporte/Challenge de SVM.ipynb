# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# El algoritmo SVM nos ayuda a clasificar observaciones en distintas categorías encontrando la frontera más grande entre ambas categorías (support vector).
#
# Esta vez es tu turno, dejamos algunos comandos para que empiezas a trabajar con el dataset :D
#
# Termina de revisarlo y responde a las preguntas de la última sección del challenge.
#
# Éxito.

# %%
import numpy as np
import pandas as pd

# %%
spotify = pd.read_csv('https://raw.githubusercontent.com/Krax7/master-data-ai/main/Kata%20Machine%20Learning/data/data_spotify.csv')
spotify = spotify.iloc[:, 1:]
spotify.head()
# Out:
#    acousticness  danceability  ...      song_title            artist
# 0        0.0102         0.833  ...        Mask Off            Future
# 1        0.1990         0.743  ...         Redbone  Childish Gambino
# 2        0.0344         0.838  ...    Xanny Family            Future
# 3        0.6040         0.494  ...  Master Of None       Beach House
# 4        0.1800         0.678  ...  Parallel Lines       Junior Boys
#
# [5 rows x 16 columns]

# %%
spotify.describe()
# Out:
#        acousticness  danceability  ...      valence       target
# count   2017.000000   2017.000000  ...  2017.000000  2017.000000
# mean       0.187590      0.618422  ...     0.496815     0.505702
# std        0.259989      0.161029  ...     0.247195     0.500091
# min        0.000003      0.122000  ...     0.034800     0.000000
# 25%        0.009630      0.514000  ...     0.295000     0.000000
# 50%        0.063300      0.631000  ...     0.492000     1.000000
# 75%        0.265000      0.738000  ...     0.691000     1.000000
# max        0.995000      0.984000  ...     0.992000     1.000000
#
# [8 rows x 14 columns]

# %%
spotify.shape
# Out:
# (2017, 16)

# %%
X = spotify.iloc[:, :13]
X.head()
# Out:
#    acousticness  danceability  duration_ms  ...    tempo  time_signature  valence
# 0        0.0102         0.833       204600  ...  150.062             4.0    0.286
# 1        0.1990         0.743       326933  ...  160.083             4.0    0.588
# 2        0.0344         0.838       185707  ...   75.044             4.0    0.173
# 3        0.6040         0.494       199413  ...   86.468             4.0    0.230
# 4        0.1800         0.678       392893  ...  174.004             4.0    0.904
#
# [5 rows x 13 columns]

# %%
y = spotify.target
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int64

# %% [markdown]
# **Ahora te toca entrenar tu modelo.**
#
# Estamos esperando que puedas trabajar con un nivel de
#
# 0.7079207920792079 de accuracy
#
# ¿Es una presentación de datos lineales o no lineales?
#
# ¿Utilizaste el truco del kernel?
#
# Crea una gráfica que nos permita visualizar el eje y el margen con relación a los datos.
#
#
# ¿Qué ventajas o problemas encuentras de usar un SVM?
#
#
# ¿Tu modelo te ayuda a clasificar una canción (respecto a las características brindadas dentro del dataset) para saber si una nueva canción sería del agrado de nuestro usuario secreto? :D
