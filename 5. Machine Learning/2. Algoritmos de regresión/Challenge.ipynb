# %% [markdown]
# # Challenge: Regresiones lineales
#
# Aquí hay un [compendio de 10 datasets libres](https://hackernoon.com/top-10-regression-datasets-for-machine-learning-projects-ce4i3wuu) a los que se puede aplicar un algoritmo de regresión lineal para realizar predicciones.
#
# ## Instrucciones
# 1. Selecciona uno de los datasets de la lista.
# 2. Selecciona una de las columnas de tu dataset como columna objetivo (tip: checa las variables categóricas).
# 3. Prepara los datos, siéntete libre realizar las tareas necesarias de limpieza o transformaciones (tip: plantéate qué columnas hace sentido conservar y busca anomalías en los datos y formato de datos).
# 4. Entrena un modelo utilizando regresión lineal.
# 5. Genera un mecanismo de evaluación para tu modelo.

# %%
# Tu código aquí
