# %% [markdown]
# # Introducción a la visualización de datos
#
# ## Historia
#
# * Para referencias de la historia de la visualización de datos podemos recurrir a los recursos [1](https://thinkinsights.net/digital/data-visualization-history/
# ),
# [2](https://towardsdatascience.com/a-short-history-of-data-visualisation-de2f81ed0b23), [3](https://hackernoon.com/what-is-data-visualization-definition-history-and-examples-e51ded6e444a) y [4](https://www.atlasobscura.com/articles/the-scottish-scoundrel-who-changed-how-we-see-data).
#
#
# Discusión de graficas chidas y feas pa discutir los principios
#
# casos de uso con código sencillo
#
# ## 4 tipos de gráficas y más
#
# * Checa la página de [50 ejemplos](https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/).
#
# * Guía de [seaborn](https://kgptalkie.com/complete-seaborn-python-tutorial-for-data-visualization-in-python/).
#
# * Mejores bibliotecas de python para [visualización](https://www.fusioncharts.com/blog/best-python-data-visualization-libraries/).
#
# usar plotly, lo básico + matplotlib + seaborn
#
# ## Comunicación, ¿qué preguntas se responden?
#
# ### links
#
# * Los mejores libros de [dataviz](
# https://www.datapine.com/blog/best-data-visualization-books/)
#
# * Correlaciones [espurias](https://www.tylervigen.com/spurious-correlations)
#
# * Catálog de [dataviz](https://datavizcatalogue.com/index.html)
#
# * Blog del libro [storytelling with data](https://www.storytellingwithdata.com/blog/)
#
# * dataset visto de [25 formas](https://flowingdata.com/2017/01/24/one-dataset-visualized-25-ways/) y una fuente de esperanza de [vida](https://www.gapminder.org/tag/life-expectancy/).

# %%
# all data charts
# https://seaborn.pydata.org/examples/index.html
# https://seaborn.pydata.org/examples/histogram_stacked.html

# https://www.python-graph-gallery.com/all-charts/
# https://www.python-graph-gallery.com/circular-barplot-basic
# https://seaborn.pydata.org/examples/facet_projections.html
# https://stackoverflow.com/questions/46750152/seaborn-polar-plot-how-to-change-degrees-in-the-facetgrid
# https://www.geeksforgeeks.org/data-visualization-with-python-seaborn/

# bad data viz / bad visualization examples in google
# http://livingqlikview.com/the-9-worst-data-visualizations-ever-created/ 
# https://towardsdatascience.com/why-is-this-chart-bad-5f16da298afa
# https://sranalytics.io/blog/bad-data-visualization-examples/

# %% [markdown]
# # Comparación
#
# ## Entre objetos
#
# ### Una variable por objeto
# 1. Tabla con gráficas incrustradas (matriz)
# 2. Gráfica de barras
# 3. Gráfica de columnas
#
# ### Dos variables por objeto
# 4. Gráfico de barras con ancho variables.
#
#
#
# ## Sobre el tiempo
#
# ### Muchos periodos
# 5. Datos cíclicos: Gráficas de área circular
# 6. Datos no cíclicos: Gráfico de línea
#
# ### Pocos periodos
# 7. Simple o para categorías: Gráfico de barras.
# 8. Muchas categorías: gráfico de líneas.

# %%
## 1. Tabla de gráficas incrustadas
## https://www.statology.org/pairs-plot-in-python/

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#define dataset
iris = sns.load_dataset("iris")

#create pairs plot for all numeric variables
sns.pairplot(iris)

# %%
iris.info()
sns.pairplot(iris, hue="species")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
fig = sns.pairplot(iris)
fig.savefig("output.png")

# %%
## otro ejemplodiscoduroexterno
## Table with embedded charts
## https://seaborn.pydata.org/examples/scatterplot_matrix.html

import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## 2 Gráfica de barras
## https://seaborn.pydata.org/generated/seaborn.barplot.html

import seaborn as sns
import numpy as np

ax = sns.barplot(x="tip", y="day", data=tips, estimator=np.median)

# %%
## 3. Gráfica de columnas
## https://seaborn.pydata.org/generated/seaborn.barplot.html

from numpy import median

ax = sns.barplot(x="day", y="tip", data=tips, estimator=median)

# %%
## 4. Variable width column chart
## https://stackoverflow.com/questions/46780367/variable-width-barplot-with-seaborn/46796963

import seaborn as sns

iris = sns.load_dataset('iris')
ax = sns.barplot('species', 'sepal_width', data=iris)
widthbars = [0.3, 0.6, 1.2]
for bar, newwidth in zip(ax.patches, widthbars):
    x = bar.get_x()
    width = bar.get_width()
    centre = x + width/2.
    bar.set_x(centre - newwidth/2.)
    bar.set_width(newwidth)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
## 5. Circular area chart with flights
## https://towardsdatascience.com/5-types-of-plots-that-will-help-you-with-time-series-analysis-b63747818705

import pandas as pd 
import numpy as np 
from datetime import datetime

# stats
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot

# plotting
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)

flights = sns.load_dataset("flights")
flights
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights['report_date'] = flights.apply(lambda x: datetime.strptime(f"{x['year']}-{x['month']}", '%Y-%b').date(), axis=1)
flights.head()
# Out:
#    year month  passengers report_date
# 0  1949   Jan         112  1949-01-01
# 1  1949   Feb         118  1949-02-01
# 2  1949   Mar         132  1949-03-01
# 3  1949   Apr         129  1949-04-01
# 4  1949   May         121  1949-05-01

# %%
fig = px.line_polar(flights, r='passengers', theta='month', 
                    color='year', line_close=True, 
                    title='Polar seasonal plot',
                    width=600, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4ae9f63b-1b48-43fe-998e-112786b9142f" class="plotly-graph-div" style="height:500px; width:600px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ae9f63b-1b48-43fe-998e-112786b9142f")) {
#                     Plotly.newPlot(
#                         '4ae9f63b-1b48-43fe-998e-112786b9142f',
# ...

# %%
## 6. Lineal chart
## https://towardsdatascience.com/5-types-of-plots-that-will-help-you-with-time-series-analysis-b63747818705

import pandas as pd 
import numpy as np 
from datetime import datetime

# stats
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot

# plotting
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)

flights = sns.load_dataset("flights")
flights['report_date'] = flights.apply(lambda x: datetime.strptime(f"{x['year']}-{x['month']}", '%Y-%b').date(), axis=1)
# flights.head()

flights.plot(x='report_date', 
             y='passengers', 
             title='Airline passengers over time');

## another source is https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/#34.-Bar-Chart

# %%
## 7. Gráfico de barras para tiempo es similar a casos anteriores
## 8. Gráfico de líneas
## https://towardsdatascience.com/5-types-of-plots-that-will-help-you-with-time-series-analysis-b63747818705

sns.lineplot(data=flights, 
             x='month', 
             y='passengers', 
             hue='year', 
             legend='full')

# add title
plt.title('Seasonal plot')

# move the legend outside of the main figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2);

# %% [markdown]
# # Composición
#
# ## Cambios temporales
#
# ### Pocos periodos
# * Solo importan diferencias relativas: Gráfico de columnas apiladas con porcentajes.
# * Importan diferencias relativas y absolutas: Gráfico de columnas apiladas.
#
# ### Muchos periodos
# * Solo importan diferencias relativas: Gráfico de áreas porcentuales apiladas.
# * Importan diferencias relativas y absolutas: Gráfico de áreas apiladas.
#
# ## Estáticos
# * Partes simples de un total: gráfica de pastel.
# * Acumulado (o resta) de un total: gráfica de cascada.
# * Componentes de componentes: Gráfica de columnas con sub componentes apilados.

# %%
## Gráfico de columnas apiladas con porcentajes.
# https://www.python-graph-gallery.com/stacked-and-percent-stacked-barplot

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# load dataset
tips = sns.load_dataset("tips")

# set the figure size
plt.figure(figsize=(9, 7))

# from raw value to percentage
total = tips.groupby('day')['total_bill'].sum().reset_index()
smoker = tips[tips.smoker=='Yes'].groupby('day')['total_bill'].sum().reset_index()
smoker['total_bill'] = [i / j * 100 for i,j in zip(smoker['total_bill'], total['total_bill'])]
total['total_bill'] = [i / j * 100 for i,j in zip(total['total_bill'], total['total_bill'])]

# bar chart 1 -> top bars (group of 'smoker=No')
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# bar chart 2 -> bottom bars (group of 'smoker=Yes')
bar2 = sns.barplot(x="day", y="total_bill", data=smoker, color='lightblue')

# add legend
top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])

# show the graph
plt.show()

# %%
## Gráfico de columnas apiladas.
#  https://www.python-graph-gallery.com/stacked-and-percent-stacked-barplot
# otro ejemplo en https://randyzwitch.com/creating-stacked-bar-chart-seaborn/

# import libraries
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# load dataset
tips = sns.load_dataset("tips")

# set plot style: grey grid in the background:
sns.set(style="darkgrid")

# set the figure size
plt.figure(figsize=(8, 6))

# top bar -> sum all values(smoker=No and smoker=Yes) to find y position of the bars
total = tips.groupby('day')['total_bill'].sum().reset_index()

# bar chart 1 -> top bars (group of 'smoker=No')
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# bottom bar ->  take only smoker=Yes values from the data
smoker = tips[tips.smoker=='Yes']

# bar chart 2 -> bottom bars (group of 'smoker=Yes')
bar2 = sns.barplot(x="day", y="total_bill", data=smoker, estimator=sum, ci=None,  color='lightblue')

# add legend
top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])

# show the graph
plt.show()

# %%
## Gráfico de áreas porcentuales apiladas. MATPLOTLIB

import numpy as np
from matplotlib import pyplot as plt

fnx = lambda : np.random.randint(5, 50, 10)
y = np.row_stack((fnx(), fnx(), fnx()))
x = np.arange(10)

# Make new array consisting of fractions of column-totals,
# using .astype(float) to avoid integer division
percent = y /  y.sum(axis=0).astype(float) * 100 

fig = plt.figure()
ax = fig.add_subplot(111)

ax.stackplot(x, percent)
ax.set_title('100 % stacked area chart')
ax.set_ylabel('Percent (%)')
ax.margins(0, 0) # Set margins to avoid "whitespace"

plt.show()

# %%
## Gráfico de áreas apiladas.
# https://www.python-graph-gallery.com/251-stacked-area-chart-with-seaborn-style
# discusión interesante en 
# https://www.data-to-viz.com/caveat/stacking.html
# otros ejemplos en
# https://holypython.com/python-visualization-tutorial/creating-stacked-area-charts-with-python/

# libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# set seaborn style
sns.set_theme()
 
# Data
x=range(1,6)
y=[ [1,4,6,8,9], [2,2,7,10,12], [2,8,5,10,6] ]
 
# Plot
plt.stackplot(x,y, labels=['A','B','C'])
plt.legend(loc='upper left')
plt.show()

# %%
## gráfica de pastel.

import matplotlib.pyplot as plt

# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0) # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
# una mejor alternativa al pie chart es el treemap
# https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/#33.-Treemap

# !pip install squarify
import squarify 
import pandas as pd
import matplotlib.pyplot as plt


# Import Data
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Prepare Data
df = df_raw.groupby('class').size().reset_index(name='counts')
labels = df.apply(lambda x: str(x[0]) + "\n (" + str(x[1]) + ")", axis=1)
sizes = df['counts'].values.tolist()
colors = [plt.cm.Spectral(i/float(len(labels))) for i in range(len(labels))]

# Draw Plot
plt.figure(figsize=(12,8), dpi= 80)
squarify.plot(sizes=sizes, label=labels, color=colors, alpha=.8)

# Decorate
plt.title('Treemap of Vechile Class')
plt.axis('off')
plt.show()

# %%
# Out:
#         class  counts
# 0     2seater       5
# 1     compact      47
# 2     midsize      41
# 3     minivan      11
# 4      pickup      33
# 5  subcompact      35
# 6         suv      62

# %%
## gráfica de cascada.
## https://www.analyticsvidhya.com/blog/2021/02/an-intuitive-guide-to-visualization-in-python/

import pandas as pd
import numpy as np

#Reading the dataset
test = pd.Series(-1 + 2 * np.random.rand(10), index=list('abcdefghij'))
#Function for makig a waterfall chart
def waterfall(series):
    df = pd.DataFrame({'pos':np.maximum(series,0),'neg':np.minimum(series,0)})
    blank = series.cumsum().shift(1).fillna(0)
    df.plot(kind='bar', stacked=True, bottom=blank, color=['r','b'], alpha=0.5)
    step = blank.reset_index(drop=True).repeat(3).shift(-1)
    step[1::3] = np.nan
    plt.plot(step.index, step.values,'k')
#Creating the waterfall chart
waterfall(test)
#Adding the aesthetics
plt.title('Chart title')
plt.xlabel('X axis title')
plt.ylabel('Y axis title')
#Show the plot
plt.show()

# %%
## Gráfica de columnas con sub componentes apilados.

# %% [markdown]
# # Relación
#
# * Dos variables: gráfico de dispersión
# * Tres variables: gráfico de burbujas
# * Cuatro variables: gráfico de burbujas de colores

# %%
## Scatter Chart / gráfico de dispersión

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

## Load the example mpg dataset
mpg = sns.load_dataset("mpg")

## Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg",
sizes=(40, 400), alpha=.5, palette="muted",
height=6, data=mpg)

plt.title("Scatter Chart 2 variables")
plt.show()

# %%
## Bubble Scatter Chart 3 variables

sns.set_theme(style="white")

## Load the example mpg dataset
mpg = sns.load_dataset("mpg")

## Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", size="weight",
sizes=(40, 400), alpha=.5, palette="muted",
height=6, data=mpg)

plt.title("Bubble Scatter Chart 3 variables")
plt.show()

# %%
## Bubble Scatter Chart 4 variables

sns.set_theme(style="white")

## Load the example mpg dataset
mpg = sns.load_dataset("mpg")

## Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
sizes=(40, 400), alpha=.5, palette="muted",
height=6, data=mpg)

plt.title("Bubble Scatter Chart 4 variables")
plt.show()

# %% [markdown]
# # Distribución
#
# ## Variable simple
# * Pocos puntos: Histograma de barras
# * Muchos puntos: Histograma de línea / densidad de probabilidad
#
# ## Dos o más variables
# * Gráfico de dispersión
# * Superficie en 3D
# * Mapa de calor

# %%
# Histograma de barras / Histogram Distribution
## https://seaborn.pydata.org/tutorial/distributions.html
x = np.random.randn(100)
sns.histplot(x)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# Histograma de líneas / densidad de probabilidad

penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm", kind="kde")

# %%
## ejemplo con más y menos granularidad
sns.displot(penguins, x="flipper_length_mm", kind="kde", bw_adjust=.25)

sns.displot(penguins, x="flipper_length_mm", kind="kde", bw_adjust=2)

# %%
# gráfica de dispersión

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="dark")
## Scatter char for distribution plots
## Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

## Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color="1")

ax.set_title("Scatter char for distribution plots")
# Out:
# Text(0.5, 1.0, 'Scatter char for distribution plots')

# %%
# superficie en 3D
# https://www.python-graph-gallery.com/371-surface-plot
# libraries
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
 
# Get the data (csv file is hosted on the web)
url = 'https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/volcano.csv'
data = pd.read_csv(url)
 
# Transform it to a long format
df=data.unstack().reset_index()
df.columns=["X","Y","Z"]
 
# And transform the old column name in something numeric
df['X']=pd.Categorical(df['X'])
df['X']=df['X'].cat.codes
 
# Make the plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
plt.show()

# %%
# heatmap
## https://seaborn.pydata.org/tutorial/distributions.html

diamonds = sns.load_dataset("diamonds")
sns.displot(diamonds, x="price", y="clarity", log_scale=(True, False))

## 
sns.displot(diamonds, x="color", y="clarity")

# %% [markdown]
# # Personalización
#
# ## Sub gráficas

# %%
# https://www.analyticsvidhya.com/blog/2021/02/an-intuitive-guide-to-visualization-in-python/

df = sns.load_dataset("iris") 
df=df.groupby('sepal_length')['sepal_width'].sum().to_frame().reset_index()
#Creating the subplot
fig, axes = plt.subplots(nrows=2, ncols=2)
ax=df.plot('sepal_length', 'sepal_width',ax=axes[0,0])
ax.get_legend().remove()
#Adding the aesthetics
ax.set_title('Chart title')
ax.set_xlabel('X axis title')
ax.set_ylabel('Y axis title')
ax=df.plot('sepal_length', 'sepal_width',ax=axes[0,1])
ax.get_legend().remove()
ax=df.plot('sepal_length', 'sepal_width',ax=axes[1,0])
ax.get_legend().remove()
ax=df.plot('sepal_length', 'sepal_width',ax=axes[1,1])
ax.get_legend().remove()
#Show the plot
plt.show()

# %% [markdown]
# # Ejemplos finales
#
# Libro [Storytelling with data](https://github.com/empathy87/storytelling-with-data).

# %%
#### https://seaborn.pydata.org/examples/part_whole_bars.html

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)
