# %% [markdown]
# # Numpy

# %% [markdown]
# ## 0) Modulos

# %% [markdown]
# [Librerias estandar de python](https://docs.python.org/3/library/)
# [Libreria math](https://docs.python.org/3/library/math.html)

# %%
import math

# %%
e = math.exp(1)
print(e)
# Out:
# 2.718281828459045

# %%
from math import sqrt

# %%
print(sqrt(9))
print(sqrt(16))
# Out:
# 3.0
# 4.0

# %%
from math import cos, sin, pi

print(cos(0), sin(0))
print(sin(pi), cos(pi))
# Out:
# 1.0 0.0
# 1.2246467991473532e-16 -1.0
# -1.2246467991473532e-16 -1.0

# %%
from math import inf as infinito

print(infinito)
print(infinito + 1)
# Out:
# inf
# inf

# %% [markdown]
# ## 1) numpy

# %% [markdown]
# Lorem ipsum

# %%
import numpy as np

# %% [markdown]
# ### Arrays

# %% [markdown]
# Lorem ipsum

# %% [markdown]
# #### Crear Arrays

# %% [markdown]
# ![create_array_1.png](data:image/png;base64,...)

# %% [markdown]
# ![create_array_2.png](data:image/png;base64,...)

# %% [markdown]
# #### Aritmética con Arrays

# %% [markdown]
# ![aritmetic_w_arrays_1.png](data:image/png;base64,...)

# %% [markdown]
# ![aritmetic_w_arrays_2.png](data:image/png;base64,...)

# %% [markdown]
# ![aritmetic_w_arrays_3.png](data:image/png;base64,...)

# %% [markdown]
# ![aritmetic_w_arrays_4.png](data:image/png;base64,...)

# %% [markdown]
# #### Indexación de arrays (Acceder a elmentos y subconjuntos)

# %% [markdown]
# ![numpy-array-slice.png](data:image/png;base64,...)

# %% [markdown]
# #### Agregación

# %% [markdown]
# ![numpy-array-aggregation.png](data:image/png;base64,...)

# %% [markdown]
# ### Matrices

# %% [markdown]
# #### Crear Matrices en Numpy

# %% [markdown]
# ![numpy-array-create-2d.png](data:image/png;base64,...)

# %% [markdown]
# ![numpy-matrix-ones-zeros-random.png](data:image/png;base64,...)

# %% [markdown]
# #### Aritmética

# %% [markdown]
# ![numpy-matrix-arithmetic.png](data:image/png;base64,...)

# %%
data = np.array([[1, 2], [3, 4]])
ones = np.ones((2, 2))

# %% [markdown]
# ![numpy-matrix-broadcast.png](data:image/png;base64,...)

# %%
data = np.array([[1, 2], [3, 4], [5, 6]])
ones_row = np.ones((1, 2))

# %% [markdown]
# #### Producto Punto

# %% [markdown]
# ![numpy-matrix-dot-product-1.png](data:image/png;base64,...)

# %%
data = np.array([[1, 2, 3]])
powers_of_ten = np.array([[1, 10], [100, 1000], [10000, 100000]])

# %% [markdown]
# ![numpy-matrix-dot-product-2.png](data:image/png;base64,...)

# %% [markdown]
# #### Indexación de matrices (Acceder a elmentos y subconjuntos)

# %% [markdown]
# ![numpy-matrix-indexing.png](data:image/png;base64,...)

# %%
data = np.array([[1, 2], [3, 4], [5, 6]])

# %% [markdown]
# #### Agregación

# %% [markdown]
# ![numpy-matrix-aggregation-1.png](data:image/png;base64,...)

# %% [markdown]
# ![numpy-matrix-aggregation-4.png](data:image/png;base64,...)

# %% [markdown]
# #### Matrices transpuestas y reshapes

# %% [markdown]
# ![numpy-transpose.png](data:image/png;base64,...)

# %% [markdown]
# ![numpy-reshape.png](data:image/png;base64,...)

# %%
data = np.array([1, 2, 3, 4, 5, 6])
