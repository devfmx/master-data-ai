# %% [markdown]
# # Leer y escribir archivos

# %%
import pandas as pd

# %% [markdown]
# ## Archivos de texto

# %% [markdown]
# ### Lectura

# %% [markdown]
# ### Escritura

# %% [markdown]
# ## Microsoft Excel

# %% [markdown]
# ### Lectura
