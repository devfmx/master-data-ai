# %% [markdown]
# # Limpieza de datos

# %%
import pandas as pd
import numpy as np

# %%
DATA_ROOT = 'https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition'
# DATA_ROOT = '.'

# %% [markdown]
# ## Datos Faltantes

# %%
string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])
string_data
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data[0] = None
string_data.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# ### Filtrando datos faltantes

# %%
from numpy import nan as NA
data = pd.Series([1, NA, 3.5, NA, 7])
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA],
                     [NA, NA, NA], [NA, 6.5, 3.]])
cleaned = data.dropna()
data
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = NA
data
data.dropna(axis=1, how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df.iloc[:4, 1] = NA
df.iloc[:2, 2] = NA
df
df.dropna()
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2  1.012690       NaN  0.611287
# 3 -0.045712       NaN  1.227024
# 4 -0.643679  0.652847  0.301489
# 5 -1.800169  0.171409 -2.040740
# 6  0.592626  0.380754  1.560841

# %% [markdown]
# ### Llenando datos faltantes

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0  0.721224  0.000000  0.000000
# 1  1.422788  0.000000  0.000000
# 2  1.012690  0.000000  0.611287
# 3 -0.045712  0.000000  1.227024
# 4 -0.643679  0.652847  0.301489
# 5 -1.800169  0.171409 -2.040740
# 6  0.592626  0.380754  1.560841

# %%
df.fillna({1: 0.5, 2: 0})
# Out:
#           0         1         2
# 0  0.721224  0.500000  0.000000
# 1  1.422788  0.500000  0.000000
# 2  1.012690  0.500000  0.611287
# 3 -0.045712  0.500000  1.227024
# 4 -0.643679  0.652847  0.301489
# 5 -1.800169  0.171409 -2.040740
# 6  0.592626  0.380754  1.560841

# %%
_ = df.fillna(0, inplace=True)
df
# Out:
#           0         1         2
# 0  0.721224  0.000000  0.000000
# 1  1.422788  0.000000  0.000000
# 2  1.012690  0.000000  0.611287
# 3 -0.045712  0.000000  1.227024
# 4 -0.643679  0.652847  0.301489
# 5 -1.800169  0.171409 -2.040740
# 6  0.592626  0.380754  1.560841

# %%
df = pd.DataFrame(np.random.randn(6, 3))
df.iloc[2:, 1] = NA
df.iloc[4:, 2] = NA
df
df.fillna(method='ffill')
df.fillna(method='ffill', limit=2)
# Out:
#           0         1         2
# 0 -0.074293  0.571168 -0.094304
# 1  1.104906 -1.083001  0.971119
# 2 -1.047708 -1.083001 -0.168392
# 3 -0.235092 -1.083001  1.633799
# 4 -0.356693       NaN  1.633799
# 5 -0.287088       NaN  1.633799

# %%
data = pd.Series([1., NA, 3.5, NA, 7])
data.fillna(data.mean())
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %% [markdown]
# ## Datos Duplicados

# %% [markdown]
# ### Quitando datos duplicados

# %%
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data['v1'] = range(7)
data.drop_duplicates(['k1'])
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
data.drop_duplicates(['k1', 'k2'], keep='last')
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6

# %% [markdown]
# ## Remplazar valores

# %% [markdown]
# ### Transformando datos usando mapeo

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon',
                              'Pastrami', 'corned beef', 'Bacon',
                              'pastrami', 'honey ham', 'nova lox'],
                     'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
  'bacon': 'pig',
  'pulled pork': 'pig',
  'pastrami': 'cow',
  'corned beef': 'cow',
  'honey ham': 'pig',
  'nova lox': 'salmon'
}

# %%
lowercased = data['food'].str.lower()
lowercased
data['animal'] = lowercased.map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %% [markdown]
# ### Metodo `.replace()`

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], np.nan)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
data.replace({-999: np.nan, -1000: 0})
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %% [markdown]
# ### Renombrar indices y columnas

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),
                    index=['Ohio', 'Colorado', 'New York'],
                    columns=['one', 'two', 'three', 'four'])

# %%
data.rename(index=str.title, columns=str.upper)
# Out:
#           ONE  TWO  THREE  FOUR
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data.rename(index={'OHIO': 'INDIANA'},
            columns={'three': 'peekaboo'})
# Out:
#           one  two  peekaboo  four
# Ohio        0    1         2     3
# Colorado    4    5         6     7
# New York    8    9        10    11

# %%
data.rename(index={'OHIO': 'INDIANA'}, inplace=True)
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %% [markdown]
# ## Discretización y creación de variables categóricas

# %% [markdown]
# ### Discretizacion y 'binning'

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

# %%
bins = [18, 25, 35, 60, 100]
cats = pd.cut(ages, bins)
cats
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
cats.codes
cats.categories
pd.value_counts(cats)
# Out:
# (18, 25]     5
# (25, 35]     3
# (35, 60]     3
# (60, 100]    1
# dtype: int64

# %%
pd.cut(ages, [18, 26, 36, 61, 100], right=False)
# Out:
# [[18, 26), [18, 26), [18, 26), [26, 36), [18, 26), ..., [26, 36), [61, 100), [36, 61), [36, 61), [26, 36)]
# Length: 12
# Categories (4, interval[int64, left]): [[18, 26) < [26, 36) < [36, 61) < [61, 100)]

# %%
group_names = ['Youth', 'YoungAdult', 'MiddleAged', 'Senior']
pd.cut(ages, bins, labels=group_names)
# Out:
# ['Youth', 'Youth', 'Youth', 'YoungAdult', 'Youth', ..., 'YoungAdult', 'Senior', 'MiddleAged', 'MiddleAged', 'YoungAdult']
# Length: 12
# Categories (4, object): ['Youth' < 'YoungAdult' < 'MiddleAged' < 'Senior']

# %%
data = np.random.rand(20)
pd.cut(data, 4, precision=2)
# Out:
# [(0.74, 0.98], (0.27, 0.5], (0.74, 0.98], (0.74, 0.98], (0.027, 0.27], ..., (0.74, 0.98], (0.27, 0.5], (0.027, 0.27], (0.5, 0.74], (0.74, 0.98]]
# Length: 20
# Categories (4, interval[float64, right]): [(0.027, 0.27] < (0.27, 0.5] < (0.5, 0.74] < (0.74, 0.98]]

# %%
data = np.random.randn(1000)  # Normally distributed
cats = pd.qcut(data, 4)  # Cut into quartiles
cats
pd.value_counts(cats)
# Out:
# (-3.298, -0.64]    250
# (-0.64, 0.0342]    250
# (0.0342, 0.752]    250
# (0.752, 3.073]     250
# dtype: int64

# %%
pd.qcut(data, [0, 0.1, 0.5, 0.9, 1.])
# Out:
# [(-1.252, 0.0342], (-1.252, 0.0342], (0.0342, 1.324], (-1.252, 0.0342], (-1.252, 0.0342], ..., (-1.252, 0.0342], (-1.252, 0.0342], (-1.252, 0.0342], (1.324, 3.073], (1.324, 3.073]]
# Length: 1000
# Categories (4, interval[float64, right]): [(-3.298, -1.252] < (-1.252, 0.0342] < (0.0342, 1.324] <
#                                            (1.324, 3.073]]

# %% [markdown]
# ### Variables indicadoras/dummy

# %%
df = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],
                   'data1': range(6)})
pd.get_dummies(df['key'])
# Out:
#    a  b  c
# 0  0  1  0
# 1  0  1  0
# 2  1  0  0
# 3  0  0  1
# 4  1  0  0
# 5  0  1  0

# %%
dummies = pd.get_dummies(df['key'], prefix='key')
df_with_dummy = df[['data1']].join(dummies)
df_with_dummy
# Out:
#    data1  key_a  key_b  key_c
# 0      0      0      1      0
# 1      1      0      1      0
# 2      2      1      0      0
# 3      3      0      0      1
# 4      4      1      0      0
# 5      5      0      1      0

# %%
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_table(DATA_ROOT + '/datasets/movielens/movies.dat', sep='::',
                       header=None, names=mnames)
movies[:10]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# 5         6                         Heat (1995)         Action|Crime|Thriller
# 6         7                      Sabrina (1995)                Comedy|Romance
# 7         8                 Tom and Huck (1995)          Adventure|Children's
# 8         9                 Sudden Death (1995)                        Action
# 9        10                    GoldenEye (1995)     Action|Adventure|Thriller

# %%
all_genres = []
for x in movies.genres:
    all_genres.extend(x.split('|'))
genres = pd.unique(all_genres)

# %%
genres
# Out:
# array(['Animation', "Children's", 'Comedy', 'Adventure', 'Fantasy',
#        'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror',
#        'Sci-Fi', 'Documentary', 'War', 'Musical', 'Mystery', 'Film-Noir',
#        'Western'], dtype=object)

# %%
zero_matrix = np.zeros((len(movies), len(genres)))
dummies = pd.DataFrame(zero_matrix, columns=genres)

# %%
gen = movies.genres[0]
gen.split('|')
dummies.columns.get_indexer(gen.split('|'))
# Out:
# array([0, 1, 2])

# %%
for i, gen in enumerate(movies.genres):
    indices = dummies.columns.get_indexer(gen.split('|'))
    dummies.iloc[i, indices] = 1

# %%
movies_windic = movies.join(dummies.add_prefix('Genre_'))
movies_windic.iloc[0]
# Out:
# movie_id                                       1
# title                           Toy Story (1995)
# genres               Animation|Children's|Comedy
# Genre_Animation                              1.0
# Genre_Children's                             1.0
# Genre_Comedy                                 1.0
# Genre_Adventure                              0.0
# Genre_Fantasy                                0.0
# Genre_Romance                                0.0
# Genre_Drama                                  0.0
# Genre_Action                                 0.0
# Genre_Crime                                  0.0
# Genre_Thriller                               0.0
# Genre_Horror                                 0.0
# Genre_Sci-Fi                                 0.0
# Genre_Documentary                            0.0
# Genre_War                                    0.0
# Genre_Musical                                0.0
# Genre_Mystery                                0.0
# Genre_Film-Noir                              0.0
# Genre_Western                                0.0
# Name: 0, dtype: object

# %%
np.random.seed(12345)
values = np.random.rand(10)
values
bins = [0, 0.2, 0.4, 0.6, 0.8, 1]
pd.get_dummies(pd.cut(values, bins))
# Out:
#    (0.0, 0.2]  (0.2, 0.4]  (0.4, 0.6]  (0.6, 0.8]  (0.8, 1.0]
# 0           0           0           0           0           1
# 1           0           1           0           0           0
# 2           1           0           0           0           0
# 3           0           1           0           0           0
# 4           0           0           1           0           0
# 5           0           0           1           0           0
# 6           0           0           0           0           1
# 7           0           0           0           1           0
# 8           0           0           0           1           0
# 9           0           0           0           1           0

# %% [markdown]
# ## Detectar y filtrar outliers

# %%
df = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],
                   'data1': range(6)})
pd.get_dummies(df['key'])
# Out:
#    a  b  c
# 0  0  1  0
# 1  0  1  0
# 2  1  0  0
# 3  0  0  1
# 4  1  0  0
# 5  0  1  0

# %%
dummies = pd.get_dummies(df['key'], prefix='key')
df_with_dummy = df[['data1']].join(dummies)
df_with_dummy
# Out:
#    data1  key_a  key_b  key_c
# 0      0      0      1      0
# 1      1      0      1      0
# 2      2      1      0      0
# 3      3      0      0      1
# 4      4      1      0      0
# 5      5      0      1      0

# %%
mnames = ['movie_id', 'title', 'genres']
movies = pd.read_table(DATA_ROOT + '/datasets/movielens/movies.dat', sep='::',
                       header=None, names=mnames)
movies[:10]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# 5         6                         Heat (1995)         Action|Crime|Thriller
# 6         7                      Sabrina (1995)                Comedy|Romance
# 7         8                 Tom and Huck (1995)          Adventure|Children's
# 8         9                 Sudden Death (1995)                        Action
# 9        10                    GoldenEye (1995)     Action|Adventure|Thriller

# %%
all_genres = []
for x in movies.genres:
    all_genres.extend(x.split('|'))
genres = pd.unique(all_genres)

# %%
genres
# Out:
# array(['Animation', "Children's", 'Comedy', 'Adventure', 'Fantasy',
#        'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror',
#        'Sci-Fi', 'Documentary', 'War', 'Musical', 'Mystery', 'Film-Noir',
#        'Western'], dtype=object)

# %%
zero_matrix = np.zeros((len(movies), len(genres)))
dummies = pd.DataFrame(zero_matrix, columns=genres)

# %%
gen = movies.genres[0]
gen.split('|')
dummies.columns.get_indexer(gen.split('|'))
# Out:
# array([0, 1, 2])

# %%
for i, gen in enumerate(movies.genres):
    indices = dummies.columns.get_indexer(gen.split('|'))
    dummies.iloc[i, indices] = 1

# %%
movies_windic = movies.join(dummies.add_prefix('Genre_'))
movies_windic.iloc[0]
# Out:
# movie_id                                       1
# title                           Toy Story (1995)
# genres               Animation|Children's|Comedy
# Genre_Animation                              1.0
# Genre_Children's                             1.0
# Genre_Comedy                                 1.0
# Genre_Adventure                              0.0
# Genre_Fantasy                                0.0
# Genre_Romance                                0.0
# Genre_Drama                                  0.0
# Genre_Action                                 0.0
# Genre_Crime                                  0.0
# Genre_Thriller                               0.0
# Genre_Horror                                 0.0
# Genre_Sci-Fi                                 0.0
# Genre_Documentary                            0.0
# Genre_War                                    0.0
# Genre_Musical                                0.0
# Genre_Mystery                                0.0
# Genre_Film-Noir                              0.0
# Genre_Western                                0.0
# Name: 0, dtype: object

# %%
np.random.seed(12345)
values = np.random.rand(10)
values
bins = [0, 0.2, 0.4, 0.6, 0.8, 1]
pd.get_dummies(pd.cut(values, bins))
# Out:
#    (0.0, 0.2]  (0.2, 0.4]  (0.4, 0.6]  (0.6, 0.8]  (0.8, 1.0]
# 0           0           0           0           0           1
# 1           0           1           0           0           0
# 2           1           0           0           0           0
# 3           0           1           0           0           0
# 4           0           0           1           0           0
# 5           0           0           1           0           0
# 6           0           0           0           0           1
# 7           0           0           0           1           0
# 8           0           0           0           1           0
# 9           0           0           0           1           0
