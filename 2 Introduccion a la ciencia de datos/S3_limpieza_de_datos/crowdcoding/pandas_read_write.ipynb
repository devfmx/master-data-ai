# %% [markdown]
# # Leer y escribir archivos

# %%
# Necesario para usar los datasets sin descargarlos
import sys
from os import path
# !{sys.executable} -m pip install opendatasets --upgrade --quiet
import opendatasets as od

if not path.isdir('imdb-extensive-dataset'):
    od.download('https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:

# %%
import opendatasets
opendatasets.download('stackoverflow-developer-survey-2020')
# Out:
# ...
# 94609408it [00:01, 48601489.89it/s]
# ...
# 16384it [00:00, 128649.61it/s]
# ...
# 8192it [00:00, 61994.67it/s]

# %%
# !ls stackoverflow-developer-survey-2020
# Out:
# README.txt  survey_results_public.csv  survey_results_schema.csv

# %%
actors = pd.read_csv('https://raw.githubusercontent.com/data-8/tutor/master/Week4/actors.csv')

# %%
len(actors)
# Out:
# 50

# %% [markdown]
# ## Archivos de texto

# %% [markdown]
# ### Lectura

# %% [markdown]
# ### Escritura

# %% [markdown]
# ## Microsoft Excel

# %% [markdown]
# ### Lectura
